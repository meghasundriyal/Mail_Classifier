# %% [markdown]
# <center>
#     <H1> NAIVE BAYES CLASSIFIER </H1>
#     <br>
# ======================================================================================================================
# <br>
# Naive Bayes Classification algorithm is a type of supervised machine learning algorithm. It is extremely easy to implement in its most basic form, and yet performs quite complex classification tasks.
# We’ll build a simple email classifier using Multinomial Naive Bayes Classifier.

# %% [markdown]
# ## STEP 1: IMPORTING LIBRARIES

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer  
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import math 
from collections import Counter, defaultdict
from sklearn.model_selection import train_test_split  
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# ## STEP 2: LOADING DATASET
#
# Load the required dataset

# %%
#mails_dataset = pd.read_csv('Dataset/trial_spam.csv', encoding = 'latin-1')
#mails_dataset = pd.read_csv('Dataset/spam.csv', encoding = 'latin-1')
mails_dataset = pd.read_csv('Dataset/emails.csv', encoding = 'latin-1')

mails_dataset.head()           #show first 5 rows
# Out:
#    sno                                   time  \
# 0    1        Tue, 17 Sep 2019 09:51:40 -0700
# 1    2  Sun, 29 Sep 2019 02:50:00 +0000 (UTC)
# 2    3  Mon, 12 Aug 2019 01:43:21 +0000 (GMT)
# 3    4  Mon, 30 Sep 2019 08:02:38 +0000 (UTC)
# 4    5  Wed, 21 Aug 2019 16:21:31 +0000 (UTC)
#
#                                              subject  \
# 0                Megha, your profile is getting hits
# 1  Building A Logistic Regression in Python, Step...
# 2   Help us protect you: Security advice from Google
# 3  Megha, start a conversation with your new conn...
# 4           Prepare for a coding interview in Python
#
#                                               sender  \
# 0  =?UTF-8?B?TGlua2VkSW4=?= <linkedin@e.linkedin....
# 1         "Medium Daily Digest" <noreply@medium.com>
# 2              Google <no-reply@accounts.google.com>
# 3  Kashish Gupta via LinkedIn <invitations@linked...
# 4           "Mari from DataCamp" <team@datacamp.com>
#
#                                                 body folder        label
# 0  Please view this email in a browser: \r\nhttps...  Inbox       Social
# 1  Today's highlights\r\n\r\nBuilding A Logistic ...  Inbox      Updates
# 2  Confirm your recovery phone\r\n\r\nmegha.mcs18...  Inbox     Personal
# 3  Kashish Gupta has accepted your invitation. Le...  Inbox       Social
# 4  Hi there,\r\n\r\nWe have 10 new courses coveri...  Inbox   Promotions

# %%
import re
print(re.findall(r'\<(.*?)\>', '"Mari from DataCamp" <team@datacamp.com>'))
# Out:
# ['team@datacamp.com']

# %% [markdown]
# ## STEP 3: FEATURE SELECTION
#
# Select the relevant features, important for mail classification. We can see that column Unamed are irrelevant for our classifier. Thus, we need to remove them.

# %%
#drop undesirable columns
#drop_list = ['Unnamed: 3', 'Unnamed: 4','Unnamed: 5','Unnamed: 6']
mails_dataset.drop(mails_dataset.columns.difference(['sno','subject','body','label']), axis = 1, inplace = True)

mails_dataset.head()
# Out:
#    sno                                            subject  \
# 0    1                Megha, your profile is getting hits
# 1    2  Building A Logistic Regression in Python, Step...
# 2    3   Help us protect you: Security advice from Google
# 3    4  Megha, start a conversation with your new conn...
# 4    5           Prepare for a coding interview in Python
#
#                                                 body        label
# 0  Please view this email in a browser: \r\nhttps...       Social
# 1  Today's highlights\r\n\r\nBuilding A Logistic ...      Updates
# 2  Confirm your recovery phone\r\n\r\nmegha.mcs18...     Personal
# 3  Kashish Gupta has accepted your invitation. Le...       Social
# 4  Hi there,\r\n\r\nWe have 10 new courses coveri...   Promotions

# %%
mails_dataset['message'] = mails_dataset[['subject', 'body']].apply(lambda x: ' '.join(x.astype(str)), axis=1)

# %%
#Rename the columns, to make it easy to read and manipulate
#mails_dataset.rename(columns = {'sno': 'docID', 'v1': 'label', 'v2': 'message'}, inplace = True)
mails_dataset.drop(['subject','body'], axis = 1, inplace = True)

mails_dataset.head()
# Out:
#    sno        label                                            message
# 0    1       Social  Megha, your profile is getting hits Please vie...
# 1    2      Updates  Building A Logistic Regression in Python, Step...
# 2    3     Personal  Help us protect you: Security advice from Goog...
# 3    4       Social  Megha, start a conversation with your new conn...
# 4    5   Promotions  Prepare for a coding interview in Python Hi th...

# %%
len(mails_dataset)
# Out:
# 681

# %%
mails_dataset['label'].value_counts()  #count number of instances of each label
# Out:
#  Personal      238
#  Social        151
#  Forums        141
#  Updates       119
#  Promotions     32
# Name: label, dtype: int64

# %%
total_mails = mails_dataset.shape[0]            #total number on instances in our dataset
total_mails
# Out:
# 681

# %% [markdown]
# ## STEP 4: DATA PREPROCESSING
#
# We need to clean our data for further processing. Emails may contain a lot of undesirable characters like punctuation marks, stop words, digits, etc which may not be helpful in detecting the class of the email

# %% [markdown]
# ###  A. Convert to lowercase

# %%
#convert the data into lower case
mails_dataset['message'] =  mails_dataset['message'].str.lower()
mails_dataset.head()
# Out:
#    sno        label                                            message
# 0    1       Social  megha, your profile is getting hits please vie...
# 1    2      Updates  building a logistic regression in python, step...
# 2    3     Personal  help us protect you: security advice from goog...
# 3    4       Social  megha, start a conversation with your new conn...
# 4    5   Promotions  prepare for a coding interview in python hi th...

# %% [markdown]
# ### B. Convert categorical values to numbers

# %%
'''
    Personal : 0
    Social : 1
    Forums : 2
    Updates : 3
    Promotions : 4
    
'''
#mails_dataset['label'] = mails_dataset['label'].map({'ham': 0, 'spam': 1})
#mails_dataset['label'] = mails_dataset['label'].map({'Personal': 0, 'Social' : 1, 'Forums' : 2,'Updates' : 3, 'Promotions' : 4})
mails_dataset.head()
# Out:
#    sno        label                                            message
# 0    1       Social  megha, your profile is getting hits please vie...
# 1    2      Updates  building a logistic regression in python, step...
# 2    3     Personal  help us protect you: security advice from goog...
# 3    4       Social  megha, start a conversation with your new conn...
# 4    5   Promotions  prepare for a coding interview in python hi th...

# %%
mails_dataset['label']=mails_dataset['label'].str.strip()

# %%
dictionary = {'Personal': 0, 'Social' : 1, 'Forums' : 2,'Updates' : 3, 'Promotions' : 4}
mails_dataset=mails_dataset.replace({"label": dictionary})
mails_dataset.head()
# Out:
#    sno  label                                            message
# 0    1      1  megha, your profile is getting hits please vie...
# 1    2      3  building a logistic regression in python, step...
# 2    3      0  help us protect you: security advice from goog...
# 3    4      1  megha, start a conversation with your new conn...
# 4    5      4  prepare for a coding interview in python hi th...

# %% [markdown]
# ### C. Remove digits and punctuations

# %%
#remove all digits
mails_dataset['message'] = mails_dataset['message'].str.replace('\d+.\d+', '')
mails_dataset.head()
# Out:
#    sno  label                                            message
# 0    1      1  megha, your profile is getting hits please vie...
# 1    2      3  building a logistic regression in python, step...
# 2    3      0  help us protect you: security advice from goog...
# 3    4      1  megha, start a conversation with your new conn...
# 4    5      4  prepare for a coding interview in python hi th...

# %%
'''
     ^   :  Not these characters
     \w  :  Word characters
     \s  :  Space characters

    Replace any character that is not a word character or a space character with nothing/blank.
    
'''
mails_dataset['message'] = mails_dataset['message'].str.replace('[^\w\s]', '')
mails_dataset.head()
# Out:
#    sno  label                                            message
# 0    1      1  megha your profile is getting hits please view...
# 1    2      3  building a logistic regression in python step ...
# 2    3      0  help us protect you security advice from googl...
# 3    4      1  megha start a conversation with your new conne...
# 4    5      4  prepare for a coding interview in python hi th...

# %%
sample_mail = mails_dataset.iloc[0]
sample_mail['message']
# Out:
# 'megha your profile is getting hits please view this email in a browser \r\nhttpselinkedincompubsfformlink_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxmtx3dyqpglljhjlyqgu2ukmcdioiucuedsd8nm5wgjocvkgokgzgni1qryl75on6zdv7zcwcdf_ei_evpx2zyzpfwmdastehmmwcjongvnq7xm_nijszrbxhbpzjyjg3d3d\r\n\r\nif you need assistance or have questions please contact linkedin customer service \r\nhttpselinkedincompubcc_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxtpkx3dswtdcsy_ei_eolaggf4snmvxff7kuckuwmuru2mcbogxku09vjwvrf62zxhf1xwquo9ggtofxh0anawteojssxgjg3d3d \r\n\r\nthis is an occasional email to help you get the most out of linkedin unsubscribe \r\nhttpselinkedincompubcc_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxtpkx3dswsuusy_ei_eolaggf4snmvxff7kuckuwmuru2mcbogxku09vj9mjfzbx7rmjiwphlqcq2lo9bykgkwjfw_qmhspmnpfx8wuujzy1pn_2zuq52as8etm7nsukdkxvmqo91cluos8gymlqczsiohieeg1emqgvotjxusdabmuafbmgoo1pv5ih8vaciga3ltbng9xojg3d3d\r\n\r\nthis email was intended for megha learn why we include this httphelplinkedincomappanswersglobalidfteng\r\n\r\ncopyright  linkedin corporation all rights reserved linkedin corp  west maude avenue sunnyvale ca \r\n\r\n'

# %% [markdown]
# ### D. Convert all the slang words to corresponding formal words
#
# Slang is the popular informal form of a word or group of words.

# %%
#create a dictionary of slang words and their corresponding terms

slang_list = {'u': 'you', 'r': 'are', 'd': "the", 'urs' : 'yours', 'wkly' : 'weekly', 'st' : 'such that', 
              'txt': 'text','comp': 'competition', 'prctc' : 'practice', 'dffrnc': 'difference', 'y': 'why', 
              'f9':'fine', 'tkts': 'tickets', 'csh': 'cash', 'phn': 'phone', 'im': 'i am', 'm': 'am', 
              'spcl': 'special', 'fone': 'phone', 'wks' : 'weeks', 'å': 'a', 'n': 'and', 'wat':'what'}

# %%
#replace slang with formal word

sample_mail = mails_dataset.iloc[0]
message = sample_mail['message']
print(message)

new_message = ' '.join(slang_list[i] if i in slang_list else i for i in message.split())
new_message
# Out:
# megha your profile is getting hits please view this email in a browser
# httpselinkedincompubsfformlink_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxmtx3dyqpglljhjlyqgu2ukmcdioiucuedsd8nm5wgjocvkgokgzgni1qryl75on6zdv7zcwcdf_ei_evpx2zyzpfwmdastehmmwcjongvnq7xm_nijszrbxhbpzjyjg3d3d
#
# if you need assistance or have questions please contact linkedin customer service
# httpselinkedincompubcc_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxtpkx3dswtdcsy_ei_eolaggf4snmvxff7kuckuwmuru2mcbogxku09vjwvrf62zxhf1xwquo9ggtofxh0anawteojssxgjg3d3d
#
# this is an occasional email to help you get the most out of linkedin unsubscribe
# httpselinkedincompubcc_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxtpkx3dswsuusy_ei_eolaggf4snmvxff7kuckuwmuru2mcbogxku09vj9mjfzbx7rmjiwphlqcq2lo9bykgkwjfw_qmhspmnpfx8wuujzy1pn_2zuq52as8etm7nsukdkxvmqo91cluos8gymlqczsiohieeg1emqgvotjxusdabmuafbmgoo1pv5ih8vaciga3ltbng9xojg3d3d
#
# this email was intended for megha learn why we include this httphelplinkedincomappanswersglobalidfteng
#
# copyright  linkedin corporation all rights reserved linkedin corp  west maude avenue sunnyvale ca
# 'megha your profile is getting hits please view this email in a browser httpselinkedincompubsfformlink_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxmtx3dyqpglljhjlyqgu2ukmcdioiucuedsd8nm5wgjocvkgokgzgni1qryl75on6zdv7zcwcdf_ei_evpx2zyzpfwmdastehmmwcjongvnq7xm_nijszrbxhbpzjyjg3d3d if you need assistance or have questions please contact linkedin customer service httpselinkedincompubcc_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxtpkx3dswtdcsy_ei_eolaggf4snmvxff7kuckuwmuru2mcbogxku09vjwvrf62zxhf1xwquo9ggtofxh0anawteojssxgjg3d3d this is an occasional email to help you get the most out of linkedin unsubscribe httpselinkedincompubcc_ri_x0gzc2x3dyqpglljhjlyqgn9zfezbymbzf35enzgsrm98sgilihzbazbkwzdwezdzebuncrk6homprvxtpkx3dswsuusy_ei_eolaggf4snmvxff7kuckuwmuru2mcbogxku09vj9mjfzbx7rmjiwphlqcq2lo9bykgkwjfw_qmhspmnpfx8wuujzy1pn_2zuq52as8etm7nsukdkxvmqo91cluos8gymlqczsiohieeg1emqgvotjxusdabmuafbmgoo1pv5ih8vaciga3ltbng9xojg3d3d this email was intended for megha learn why we include this httphelplinkedincomappanswersglobalidfteng copyright linkedin corporation all rights reserved linkedin corp west maude avenue sunnyvale ca'

# %%
#applying to all rows

def convert_slangs(row):
    message = row['message']
    new_message = ' '.join(slang_list[i] if i in slang_list else i for i in message.split())
    return new_message

mails_dataset['message'] = mails_dataset.apply(convert_slangs, axis=1)
mails_dataset.head()
# Out:
#    sno  label                                            message
# 0    1      1  megha your profile is getting hits please view...
# 1    2      3  building a logistic regression in python step ...
# 2    3      0  help us protect you security advice from googl...
# 3    4      1  megha start a conversation with your new conne...
# 4    5      4  prepare for a coding interview in python hi th...

# %% [markdown]
# ### E. Tokenization

# %%
#pick every message and convert it into tokens

def identify_tokens(row):
    message = row['message']
    tokens = word_tokenize(message)
    token_words = [w for w in tokens if w.isalpha()]
    return token_words

mails_dataset['tokens'] = mails_dataset.apply(identify_tokens, axis=1)
mails_dataset.head()
# Out:
#    sno  label                                            message  \
# 0    1      1  megha your profile is getting hits please view...
# 1    2      3  building a logistic regression in python step ...
# 2    3      0  help us protect you security advice from googl...
# 3    4      1  megha start a conversation with your new conne...
# 4    5      4  prepare for a coding interview in python hi th...
#
#                                               tokens
# 0  [megha, your, profile, is, getting, hits, plea...
# 1  [building, a, logistic, regression, in, python...
# 2  [help, us, protect, you, security, advice, fro...
# 3  [megha, start, a, conversation, with, your, ne...
# 4  [prepare, for, a, coding, interview, in, pytho...

# %% [markdown]
# ### F. Stemming / Lemmatization
#
# Both processes reduce the inflectional forms of word into a common base or root. But we are using lemmatization because it takes care of the context, while stemming simply performs crude cutoff...

# %%
'''
stemming = PorterStemmer()
sample_mail = mails_dataset.iloc[0]
tokens = sample_mail['tokens']
stemmed_list = [stemming.stem(word) for word in tokens]
stemmed_list
'''
# Out:
# "\nstemming = PorterStemmer()\nsample_mail = mails_dataset.iloc[0]\ntokens = sample_mail['tokens']\nstemmed_list = [stemming.stem(word) for word in tokens]\nstemmed_list\n"

# %%
lemmatizer = WordNetLemmatizer() 

sample_mail = mails_dataset.iloc[0]
tokens = sample_mail['tokens']
lemmatize_list = [lemmatizer.lemmatize(word) for word in tokens]
lemmatize_list
# Out:
# ['megha',
#  'your',
#  'profile',
#  'is',
#  'getting',
#  'hit',
#  'please',
#  'view',
#  'this',
#  'email',
#  'in',
#  'a',
#  'browser',
#  'if',
#  'you',
#  'need',
#  'assistance',
#  'or',
#  'have',
#  'question',
#  'please',
#  'contact',
#  'linkedin',
#  'customer',
#  'service',
#  'this',
#  'is',
#  'an',
#  'occasional',
#  'email',
#  'to',
#  'help',
#  'you',
#  'get',
#  'the',
#  'most',
#  'out',
#  'of',
#  'linkedin',
#  'unsubscribe',
#  'this',
#  'email',
#  'wa',
#  'intended',
#  'for',
#  'megha',
#  'learn',
#  'why',
#  'we',
#  'include',
#  'this',
#  'httphelplinkedincomappanswersglobalidfteng',
#  'copyright',
#  'linkedin',
#  'corporation',
#  'all',
#  'right',
#  'reserved',
#  'linkedin',
#  'corp',
#  'west',
#  'maude',
#  'avenue',
#  'sunnyvale',
#  'ca']

# %%
def lemmatize_tokens(row):
    tokens = row['tokens']
    lemmatized_list = [lemmatizer.lemmatize(word) for word in tokens]
    return (lemmatized_list)

mails_dataset['tokens'] = mails_dataset.apply(lemmatize_tokens, axis=1)
mails_dataset.head()
# Out:
#    sno  label                                            message  \
# 0    1      1  megha your profile is getting hits please view...
# 1    2      3  building a logistic regression in python step ...
# 2    3      0  help us protect you security advice from googl...
# 3    4      1  megha start a conversation with your new conne...
# 4    5      4  prepare for a coding interview in python hi th...
#
#                                               tokens
# 0  [megha, your, profile, is, getting, hit, pleas...
# 1  [building, a, logistic, regression, in, python...
# 2  [help, u, protect, you, security, advice, from...
# 3  [megha, start, a, conversation, with, your, ne...
# 4  [prepare, for, a, coding, interview, in, pytho...

# %% [markdown]
# ### G. Remove stopwords
#
# Stopwords are common words that carry less important meaning than keywords. So, we will remove them.

# %%
stop_words = set(stopwords.words('english'))
print(stop_words,)
# Out:
# {'him', 'no', 'is', "couldn't", 'by', 'which', 'isn', 'all', 'shouldn', 'yourself', 'does', 'the', "you're", 'your', 'yours', 'himself', 'too', 'below', "you'd", 'on', 'll', 'she', 'couldn', 'me', 'myself', 'been', "shouldn't", 'up', 'it', 'down', 'are', 'just', 'ourselves', 'we', 'when', 'do', "that'll", 'doing', 'because', 'did', 'our', 'before', 'very', 'can', "you'll", 'wasn', "wouldn't", 's', "hasn't", 'being', 'his', 'than', 'until', 'some', 't', 'needn', 'theirs', 'these', 'herself', 'mightn', 'so', 'where', 'you', 'her', "it's", 'in', 'between', 'other', 'ours', 'this', 'for', 'not', 'then', 'such', 'wouldn', 'should', "should've", 'or', 'an', "shan't", 'y', "doesn't", 'had', 'most', 'after', 'more', 'hadn', 'm', 'here', 'there', 'am', 'd', 're', 'while', 'about', 'don', 'ain', 'over', 'each', 'was', 'but', 'further', 'hers', 'at', 'above', 'own', "isn't", 'from', 'hasn', 'any', 'were', 'itself', "she's", 'as', "won't", "didn't", 'having', 'now', 'why', 'how', "you've", 'with', "wasn't", 'if', 'haven', 'will', "weren't", "haven't", 'themselves', 'shan', 'my', 'their', 'once', 'them', 'those', 'off', 'whom', "hadn't", 'under', "mightn't", 'have', 'again', 'yourselves', 'nor', "needn't", 'won', 'i', 'few', 'he', 'and', 'only', 'be', 'same', "don't", 've', 'they', 'has', 'weren', 'against', 'through', 'o', 'what', 'to', 'out', "mustn't", 'during', 'who', 'didn', 'of', 'that', 'doesn', 'into', 'mustn', 'both', 'aren', "aren't", 'ma', 'its', 'a'}

# %%
def remove_stopwords(row):
    tokens = row['tokens']
    filtered_list = [w for w in tokens if not w in stop_words]
    return (filtered_list)

mails_dataset['tokens'] = mails_dataset.apply(remove_stopwords , axis=1)
mails_dataset.head()
# Out:
#    sno  label                                            message  \
# 0    1      1  megha your profile is getting hits please view...
# 1    2      3  building a logistic regression in python step ...
# 2    3      0  help us protect you security advice from googl...
# 3    4      1  megha start a conversation with your new conne...
# 4    5      4  prepare for a coding interview in python hi th...
#
#                                               tokens
# 0  [megha, profile, getting, hit, please, view, e...
# 1  [building, logistic, regression, python, step,...
# 2  [help, u, protect, security, advice, google, c...
# 3  [megha, start, conversation, new, connection, ...
# 4  [prepare, coding, interview, python, hi, new, ...

# %% [markdown]
# ## >>>> Now our data is cleaned and ready for training <<<<

# %% [markdown]
# ## STEP 5: CREATING TEST AND TRAIN SETS
#
# We will randomly split our dataset in 80–20 ratio. Where 80% of the total data will be used as training set and rest 20% will be considered as test set.

# %%
#before splitting. Let's, create vocabulary

all_tokens = []

for row in range(total_mails):
        #pick every token list from each row and append to the all tokens list
        tokens = mails_dataset.tokens.iloc[row]
        #append the list to the final list 
        all_tokens += tokens 
    
vocab = np.unique(all_tokens)      #vocabulary is the collection of all terms in the corpus

print("Total number of tokens in the corpus : ", len(all_tokens))
print("Total terms : ", len(vocab))
# Out:
# Total number of tokens in the corpus :  61583
# Total terms :  7686

# %%
X = mails_dataset.drop('label',axis=1) 
y = mails_dataset['label']

#random state = 0, will give same split evry time. 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
test_size, train_size = X_test.shape[0], X_train.shape[0]
print("Number of instance in :\n Training set = ", train_size, "\n Test set = ", test_size)
# Out:
# Number of instance in :
#  Training set =  544
#  Test set =  137

# %%
X_train.head()
# Out:
#      sno                                            message  \
# 200  263  megha start a conversation with your new conne...
# 380  514  advice from a 33yearold who wants you to stop ...
# 236  312  collection hello juniors we hope you all are d...
# 101  133  graphs for average comparisons forwarded messa...
# 667  904  student volunteers for ducs alumni assocation ...
#
#                                                 tokens
# 200  [megha, start, conversation, new, connection, ...
# 380  [advice, want, stop, worrying, much, tim, denn...
# 236  [collection, hello, junior, hope, well, said, ...
# 101  [graph, average, comparison, forwarded, messag...
# 667  [student, volunteer, ducs, alumnus, assocation...

# %%
#y_train is an array. so in order to concat it with our X variables, we need to convert it into dataframe

labels_train = pd.DataFrame(y_train, columns = ['label'])
labels_train.head()
# Out:
#      label
# 200      1
# 380      3
# 236      2
# 101      0
# 667      0

# %%
'''
    We have X_train, y_train, X_test, y_test.
    Using these lists and dataframes we will randomly create two non-overlapping datasets 
        1. training set
        2. testing set
'''

#creating training set
train_set = pd.concat([X_train, labels_train], axis = 1).reset_index(drop=True)
train_set.head()
# Out:
#    sno                                            message  \
# 0  263  megha start a conversation with your new conne...
# 1  514  advice from a 33yearold who wants you to stop ...
# 2  312  collection hello juniors we hope you all are d...
# 3  133  graphs for average comparisons forwarded messa...
# 4  904  student volunteers for ducs alumni assocation ...
#
#                                               tokens  label
# 0  [megha, start, conversation, new, connection, ...      1
# 1  [advice, want, stop, worrying, much, tim, denn...      3
# 2  [collection, hello, junior, hope, well, said, ...      2
# 3  [graph, average, comparison, forwarded, messag...      0
# 4  [student, volunteer, ducs, alumnus, assocation...      0

# %%
# Our training set is ready, similarly creating test set

labels_test = pd.DataFrame(y_test, columns = ['label'])
test_set = pd.concat([X_test, labels_test], axis = 1).reset_index(drop=True)
test_set.head()
# Out:
#    sno                                            message  \
# 0  146  megha thanks for being an active member please...
# 1  805  shrikant and manish sent new messages messages...
# 2  337  shrikant sent you a new message conversation w...
# 3  750  delivery status notification failure hello meg...
# 4  373                       mcs_exploratory analysis pfa
#
#                                               tokens  label
# 0  [megha, thanks, active, member, please, view, ...      1
# 1  [shrikant, manish, sent, new, message, message...      1
# 2  [shrikant, sent, new, message, conversation, s...      3
# 3  [delivery, status, notification, failure, hell...      0
# 4                                    [analysis, pfa]      0

# %% [markdown]
# Our dataset is divided into two parts : train_set and test_set. Now we need to train our model

# %% [markdown]
# ## STEP 6: TRAINING CLASSIFIER

# %% [markdown]
# ## <center>  Multinomial Naive Bayes Classifier
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### A . Compute prior probability of each class
#
# Prior probaility of class c, is computed as:
#
#    <center><b> P(c) = (examples with label c) / (total examples)

# %%
total_classes = train_set['label'].nunique()
total_classes      # total number of classes
# Out:
# 5

# %%
# create set of all instances wth class label = 1
y1 = train_set[train_set.label == 1]

#instances with class label = 1 
y1.head()
# Out:
#     sno                                            message  \
# 0   263  megha start a conversation with your new conne...
# 5   778  megha start a conversation with your new conne...
# 7   532  megha start a conversation with your new conne...
# 11  914  megha please add me to your linkedin network h...
# 13  916  himanshu sent you a new message conversation w...
#
#                                                tokens  label
# 0   [megha, start, conversation, new, connection, ...      1
# 5   [megha, start, conversation, new, connection, ...      1
# 7   [megha, start, conversation, new, connection, ...      1
# 11  [megha, please, add, linkedin, network, hi, me...      1
# 13  [himanshu, sent, new, message, conversation, h...      1

# %%
#now calculate the prior probaility of each label/class

prior_prob = {}          #empty array
class_set = {}           #divide the instances into classes

#create set of examples with same class labels and then compute prior prob of each class

for ci in range(total_classes):
    class_set[ci] = train_set[train_set.label == ci]     
    count_label = len(class_set[ci])
    prior_prob[ci] = count_label/train_size       
    
prior_prob
# Out:
# {0: 0.35661764705882354,
#  1: 0.22242647058823528,
#  2: 0.20772058823529413,
#  3: 0.1636029411764706,
#  4: 0.04963235294117647}

# %% [markdown]
# ### B. Creating Bag of Words for each class
#
# Create a BOW model and count number of times each term occurs in each class.

# %%
from collections import Counter
z = ['blue', 'red', 'blue', 'yellow', 'blue', 'red']
Counter(z)
# Out:
# Counter({'blue': 3, 'red': 2, 'yellow': 1})

# %%
#create bow for each class
bow_class = {}        #set to store bow of each class

#for every class ci
for ci in range(total_classes):
    tokens_class = []            #create empty list of tokens in class ci
    for row in range(len(class_set[ci])):
        #pick tokens from each row and append to the row tokens list
        tokens = class_set[ci].tokens.iloc[row]
        #append the list to the final list 
        tokens_class.extend(tokens) 
    
    bow_class[ci] = tokens_class      # bow of class ci

#bow_class[0]

# %%
# calculate the number of occurrences of each term in each class 
# Counter returns a dictionary where key is the term and value is the no of time it occurs 

freq_terms_class = {}

for ci in range(total_classes):
    freq_terms_class[ci] = dict(Counter(bow_class[ci]))

freq_terms_class[0]
# Out:
# {'graph': 13,
#  'average': 1,
#  'comparison': 2,
#  'forwarded': 51,
#  'message': 66,
#  'megha': 65,
#  'surname': 1,
#  'date': 88,
#  'wed': 16,
#  'aug': 26,
#  'pm': 77,
#  'subject': 60,
#  'student': 102,
#  'volunteer': 5,
#  'ducs': 5,
#  'alumnus': 8,
#  'assocation': 2,
#  'dear': 37,
#  'need': 12,
#  'two': 7,
#  'every': 2,
#  'batch': 2,
#  'association': 2,
#  'pls': 12,
#  'provide': 5,
#  'name': 20,
#  'sapna': 14,
#  'varshney': 13,
#  'assistant': 13,
#  'professor': 16,
#  'adhoc': 6,
#  'department': 61,
#  'computer': 66,
#  'science': 72,
#  'university': 75,
#  'delhi': 107,
#  'fwd': 50,
#  'india': 38,
#  'fest': 2,
#  'bring': 6,
#  'world': 8,
#  'vasudha': 23,
#  'bhatnagar': 24,
#  'vasudhabhatnagargmailcom': 15,
#  'sun': 18,
#  'sapnavarshgmailcom': 6,
#  'ronnie': 1,
#  'chakre': 9,
#  'mca': 46,
#  'elective': 4,
#  'form': 31,
#  'ratheepriyankagmailcom': 4,
#  'fri': 16,
#  'dec': 1,
#  'image': 61,
#  'google': 86,
#  'fill': 10,
#  'option': 8,
#  'choose': 1,
#  'algo': 16,
#  'hw': 1,
#  'list': 25,
#  'correctness': 1,
#  'insertion': 2,
#  'sort': 2,
#  'tn': 2,
#  'prove': 6,
#  'tnanb': 1,
#  'constant': 3,
#  'lim': 2,
#  'ninfinity': 2,
#  'fngn': 2,
#  'fn': 2,
#  'ogn': 1,
#  'first': 11,
#  'definition': 2,
#  'c': 12,
#  'thetagn': 1,
#  'log': 3,
#  'nm': 1,
#  'onâ': 1,
#  'however': 1,
#  'large': 3,
#  'small': 3,
#  'logan': 1,
#  'thetalogbn': 1,
#  'base': 1,
#  'doesnt': 1,
#  'matter': 1,
#  'limit': 1,
#  'tntfloorn': 1,
#  'onlogn': 1,
#  'formation': 7,
#  'ieee': 14,
#  'branch': 9,
#  'regard': 32,
#  'office': 23,
#  'priyanka': 7,
#  'rathee': 5,
#  'tue': 25,
#  'himani': 4,
#  'saini': 1,
#  'officecsdugmailcom': 7,
#  'planning': 1,
#  'start': 5,
#  'ie': 4,
#  'provides': 3,
#  'opportunity': 19,
#  'meet': 3,
#  'learn': 22,
#  'fellow': 2,
#  'member': 8,
#  'engage': 1,
#  'professional': 9,
#  'locally': 1,
#  'active': 4,
#  'one': 7,
#  'positive': 1,
#  'element': 1,
#  'college': 6,
#  'offering': 1,
#  'program': 11,
#  'activity': 14,
#  'networking': 1,
#  'faculty': 7,
#  'support': 2,
#  'well': 5,
#  'signature': 1,
#  'least': 4,
#  'needed': 1,
#  'petition': 1,
#  'benefit': 2,
#  'given': 11,
#  'document': 8,
#  'attached': 22,
#  'information': 13,
#  'please': 56,
#  'feel': 3,
#  'free': 19,
#  'contact': 9,
#  'dr': 13,
#  'thanks': 27,
#  'chairperson': 3,
#  'young': 8,
#  'section': 6,
#  'mathematical': 3,
#  'floor': 7,
#  'new': 39,
#  'academic': 11,
#  'block': 6,
#  'find': 12,
#  'linkedin': 13,
#  'wwwlinkedincominpriyankarathee': 3,
#  'dip': 7,
#  'ppt': 21,
#  'updated': 12,
#  'mon': 23,
#  'sundriyal': 41,
#  'wrote': 49,
#  'lot': 4,
#  'roni': 13,
#  'ronniechakregmailcom': 7,
#  'hello': 10,
#  'antivirus': 2,
#  'file': 20,
#  'closure': 1,
#  'prog': 1,
#  'input': 1,
#  'format': 2,
#  'abcdefgh': 1,
#  'fds': 2,
#  'ab': 4,
#  'de': 1,
#  'b': 4,
#  'f': 1,
#  'fg': 1,
#  'h': 7,
#  'doe': 4,
#  'work': 6,
#  'alpha': 1,
#  'value': 2,
#  'invitation': 18,
#  'onload': 6,
#  'hackathon': 7,
#  'vbhatnagarcsduacin': 8,
#  'feb': 11,
#  'du': 21,
#  'cc': 7,
#  'svarshneycsduacin': 1,
#  'forward': 18,
#  'cr': 9,
#  'vb': 5,
#  'contacthackonloadcom': 1,
#  'vbhatnagar': 1,
#  'sent': 5,
#  'tuesday': 6,
#  'february': 15,
#  'team': 18,
#  'behind': 1,
#  'privileged': 1,
#  'invite': 7,
#  'esteemed': 1,
#  'institute': 1,
#  'attend': 2,
#  'event': 6,
#  'intense': 1,
#  'funfilled': 1,
#  'rewarding': 1,
#  'convergence': 2,
#  'talented': 1,
#  'programmer': 1,
#  'designer': 1,
#  'developer': 3,
#  'country': 3,
#  'working': 2,
#  'together': 1,
#  'build': 1,
#  'something': 1,
#  'amazing': 1,
#  'cutting': 1,
#  'edge': 1,
#  'technology': 8,
#  'including': 2,
#  'limited': 4,
#  'artificial': 7,
#  'intelligence': 11,
#  'machine': 15,
#  'learning': 24,
#  'blockchain': 1,
#  'iot': 2,
#  'many': 4,
#  'leveraging': 1,
#  'available': 9,
#  'tool': 3,
#  'apis': 1,
#  'creating': 2,
#  'towards': 2,
#  'common': 5,
#  'goal': 1,
#  'better': 4,
#  'happening': 1,
#  'mysuru': 1,
#  'palace': 1,
#  'city': 9,
#  'march': 8,
#  'website': 3,
#  'httpshackonloadcom': 1,
#  'make': 17,
#  'greater': 1,
#  'request': 9,
#  'share': 10,
#  'get': 23,
#  'utmost': 1,
#  'develop': 2,
#  'skill': 2,
#  'attending': 1,
#  'would': 4,
#  'appreciate': 1,
#  'reach': 2,
#  'institution': 2,
#  'side': 2,
#  'fruitful': 1,
#  'reaction': 1,
#  'participation': 9,
#  'promising': 1,
#  'hand': 1,
#  'grand': 1,
#  'success': 1,
#  'session': 6,
#  'held': 9,
#  'notice': 5,
#  'per': 3,
#  'detail': 14,
#  'following': 10,
#  'schedule': 1,
#  'presentation': 3,
#  'sudhanshu': 1,
#  'vishnoi': 1,
#  'sem': 11,
#  'v': 5,
#  'present': 7,
#  'gsoc': 1,
#  'project': 30,
#  'titled': 2,
#  'implementing': 1,
#  'cross': 2,
#  'reference': 6,
#  'general': 1,
#  'improvement': 6,
#  'respec': 2,
#  'mozilla': 1,
#  'implement': 1,
#  'feature': 1,
#  'fix': 1,
#  'existing': 2,
#  'issue': 3,
#  'improve': 3,
#  'maintainability': 1,
#  'zoo': 1,
#  'âerror': 1,
#  'error': 6,
#  'foundâ': 1,
#  'runnerup': 5,
#  'position': 4,
#  'alexa': 1,
#  'voicebased': 1,
#  'wildlife': 4,
#  'guru': 1,
#  'product': 5,
#  'specie': 1,
#  'trade': 1,
#  'law': 6,
#  'organization': 2,
#  'contacted': 2,
#  'report': 10,
#  'crime': 6,
#  'etc': 5,
#  'day': 16,
#  'monday': 3,
#  'november': 3,
#  'time': 27,
#  'venue': 4,
#  'seminar': 2,
#  'room': 1,
#  'â': 38,
#  'cordially': 3,
#  'invited': 2,
#  'nan': 9,
#  'perlakh': 5,
#  'pca': 7,
#  'year': 76,
#  'normalised': 4,
#  'data': 30,
#  'apr': 23,
#  'abhishek': 16,
#  'sen': 14,
#  'studio': 8,
#  'connected': 6,
#  'account': 41,
#  'hi': 5,
#  'ha': 18,
#  'access': 17,
#  'view': 33,
#  'manage': 4,
#  'drive': 6,
#  'give': 9,
#  'apps': 4,
#  'trust': 2,
#  'review': 3,
#  'remove': 2,
#  'httpsmyaccountgooglecompermissions': 2,
#  'httpssupportgooglecomaccountsanswer': 4,
#  'mean': 2,
#  'connect': 6,
#  'app': 2,
#  'email': 61,
#  'cant': 2,
#  'receive': 2,
#  'reply': 3,
#  'visit': 23,
#  'help': 16,
#  'center': 7,
#  'received': 27,
#  'mandatory': 2,
#  'service': 12,
#  'announcement': 2,
#  'update': 6,
#  'important': 18,
#  'change': 22,
#  'llc': 13,
#  'amphitheatre': 13,
#  'parkway': 13,
#  'mountain': 13,
#  'ca': 13,
#  'usa': 13,
#  'security': 23,
#  'alert': 10,
#  'someone': 2,
#  'signed': 16,
#  'device': 18,
#  'location': 1,
#  'want': 19,
#  'sure': 12,
#  'dont': 6,
#  'recognize': 1,
#  'sign': 1,
#  'password': 4,
#  'right': 2,
#  'away': 1,
#  'unsubscribe': 12,
#  'receiving': 11,
#  'notification': 5,
#  'wa': 19,
#  'intended': 1,
#  'included': 3,
#  'ireland': 2,
#  'unlimited': 2,
#  'company': 3,
#  'wilton': 2,
#  'plaza': 1,
#  'place': 3,
#  'dublin': 1,
#  'registered': 6,
#  'business': 8,
#  'logo': 2,
#  'trademark': 9,
#  'dbms': 2,
#  'practical': 3,
#  'couldnt': 2,
#  'send': 21,
#  'javascript': 1,
#  'added': 2,
#  'link': 20,
#  'code': 4,
#  'inside': 1,
#  'zip': 2,
#  'aos': 6,
#  'issuing': 1,
#  'deptt': 9,
#  'laptop': 4,
#  'summer': 1,
#  'vacation': 1,
#  'class': 33,
#  'requested': 4,
#  'kindly': 7,
#  'inform': 3,
#  'genuinely': 1,
#  'requirement': 4,
#  'projectplacementvacation': 1,
#  'lab': 2,
#  'submit': 1,
#  'application': 7,
#  'plain': 1,
#  'paper': 9,
#  'genuine': 1,
#  'reason': 5,
#  'addressing': 1,
#  'hod': 2,
#  'devki': 1,
#  'rawat': 1,
#  'incharge': 1,
#  'ext': 1,
#  'numpy': 1,
#  'ayush': 5,
#  'chhavi': 3,
#  'remcs': 1,
#  'test': 11,
#  'div': 9,
#  'dirltrok': 1,
#  'let': 25,
#  'know': 28,
#  'shortly': 2,
#  'studentsbr': 1,
#  'divdiv': 16,
#  'dirltrbr': 11,
#  'redmi': 5,
#  'may': 47,
#  'wrotebr': 1,
#  'typeattributionblockquote': 3,
#  'classquote': 3,
#  'stylemargin': 3,
#  'ccc': 3,
#  'dirautogood': 1,
#  'evening': 7,
#  'dirautopfb': 1,
#  'testâ': 1,
#  'dirautodiv': 1,
#  'dirautobrdivdiv': 3,
#  'radhnandanidivdiv': 1,
#  'sangeetadivdiv': 1,
#  'updeshdivdiv': 1,
#  'ruchidivdiv': 1,
#  'saurav': 9,
#  'meenadivdiv': 1,
#  'deepadivdiv': 1,
#  'absent': 2,
#  'assignment': 10,
#  'possible': 9,
#  'another': 2,
#  'assignmentdivdiv': 1,
#  'dirautothank': 1,
#  'youâ': 1,
#  'dirautomegha': 1,
#  'sundriyaldivdivdiv': 1,
#  'blockquotediv': 3,
#  'midsemester': 2,
#  'break': 2,
#  'thru': 2,
#  'vbducsgmailcom': 7,
#  'sep': 11,
#  'krishna': 7,
#  'ia': 4,
#  'discrepancy': 3,
#  'tomorrow': 2,
#  'final': 13,
#  'msccs': 7,
#  'iii': 21,
#  'minor': 20,
#  'preference': 15,
#  'jul': 1,
#  'sai': 1,
#  'window': 5,
#  'youre': 7,
#  'getting': 10,
#  'check': 21,
#  'naac': 6,
#  'peer': 10,
#  'meeting': 3,
#  'greeting': 4,
#  'behalf': 1,
#  'offer': 4,
#  'felicitation': 1,
#  'part': 3,
#  'distinguished': 1,
#  'heartening': 1,
#  'note': 13,
#  'ranked': 4,
#  'centre': 3,
#  'ranking': 2,
#  'cwur': 1,
#  'among': 5,
#  'q': 3,
#  'national': 2,
#  'level': 1,
#  'also': 22,
#  'top': 5,
#  'brics': 1,
#  'region': 2,
#  'happy': 1,
#  'based': 8,
#  'submitted': 1,
#  'feedback': 1,
#  'assessment': 5,
#  'accreditation': 3,
#  'council': 2,
#  'decided': 1,
#  'octoberâ': 1,
#  'since': 5,
#  'expected': 1,
#  'strengthen': 1,
#  'coveted': 1,
#  'cherished': 1,
#  'duty': 1,
#  'contribute': 1,
#  'impending': 1,
#  'scheduled': 1,
#  'convention': 2,
#  'hall': 3,
#  'vice': 3,
#  'regal': 1,
#  'lodge': 2,
#  'advised': 2,
#  'carry': 1,
#  'icard': 1,
#  'verification': 4,
#  'understanding': 2,
#  'component': 1,
#  'glad': 2,
#  'mention': 4,
#  'response': 4,
#  'earlier': 2,
#  'survey': 1,
#  'regarding': 5,
#  'âoverall': 1,
#  'experienceâ': 1,
#  'always': 1,
#  'remained': 1,
#  'âvery': 1,
#  'goodâ': 1,
#  'reflects': 1,
#  'overall': 1,
#  'quality': 1,
#  'research': 2,
#  'programme': 1,
#  'offered': 1,
#  'valuable': 1,
#  'contribution': 1,
#  'ensure': 2,
#  'completes': 1,
#  'exercise': 1,
#  'successfully': 1,
#  'wishing': 1,
#  'best': 16,
#  'future': 2,
#  'wish': 6,
#  'dean': 9,
#  'scribe': 23,
#  'thing': 4,
#  'proper': 1,
#  'indentation': 1,
#  'everything': 1,
#  'left': 7,
#  'able': 4,
#  'put': 4,
#  'equation': 2,
#  'lhopital': 1,
#  'aligned': 1,
#  'coming': 1,
#  'internet': 1,
#  'tick': 1,
#  'latex': 1,
#  'table': 8,
#  'unemployment': 1,
#  'dataset': 2,
#  'matlab': 51,
#  'simulink': 34,
#  'resource': 9,
#  'academia': 6,
#  'thu': 9,
#  'mar': 13,
#  'fyi': 4,
#  'homepage': 5,
#  'peopleduacinvbhatnagar': 5,
#  'anand': 4,
#  'geethagovindan': 4,
#  'anandgeethagovindangomathworkscom': 2,
#  'mathworks': 16,
#  'certification': 4,
#  'ai': 25,
#  'robotics': 4,
#  'arena': 3,
#  'upcoming': 6,
#  'webinars': 6,
#  'training': 14,
#  'web': 13,
#  'page': 5,
#  'click': 10,
#  'career': 2,
#  'establishes': 1,
#  'standard': 1,
#  'excellence': 1,
#  'demonstrates': 1,
#  'proficiency': 1,
#  'customer': 1,
#  'industry': 2,
#  'employer': 1,
#  'featured': 2,
#  'everywhere': 1,
#  'powering': 1,
#  'like': 8,
#  'smart': 1,
#  'translation': 1,
#  'automated': 4,
#  'driving': 4,
#  'giving': 1,
#  'engineer': 1,
#  'scientist': 4,
#  'set': 3,
#  'technique': 2,
#  'tackling': 1,
#  'task': 4,
#  'way': 6,
#  'download': 8,
#  'ebook': 4,
#  'gartner': 3,
#  'recognized': 2,
#  'visionary': 2,
#  'magic': 2,
#  'quadrant': 2,
#  'january': 5,
#  'platform': 1,
#  'read': 3,
#  'blog': 1,
#  'modeling': 3,
#  'pneumatic': 3,
#  'robot': 2,
#  'actuator': 2,
#  'join': 4,
#  'veer': 1,
#  'alakshendra': 1,
#  'maitreyee': 1,
#  'mordekar': 1,
#  'discus': 2,
#  'simulation': 3,
#  'system': 7,
#  'relevant': 1,
#  'competition': 5,
#  'robocon': 1,
#  'watch': 4,
#  'video': 5,
#  'complimentary': 3,
#  'software': 3,
#  'supra': 3,
#  'saeindia': 3,
#  'participating': 4,
#  'developing': 4,
#  'dcdc': 2,
#  'converter': 4,
#  'control': 4,
#  'register': 23,
#  'predictive': 3,
#  'maintenance': 3,
#  'prognostic': 3,
#  'case': 7,
#  'study': 11,
#  'started': 4,
#  'vehicle': 5,
#  'dynamic': 1,
#  'blockset': 1,
#  'vdbs': 1,
#  'design': 11,
#  'combinatorial': 3,
#  'sequential': 1,
#  'logic': 1,
#  'using': 5,
#  'state': 3,
#  'stateflow': 1,
#  'classroom': 1,
#  'ready': 2,
#  'arduino': 1,
#  'engineering': 9,
#  'kit': 1,
#  'full': 2,
#  'demand': 6,
#  'deep': 7,
#  'selfpaced': 3,
#  'course': 8,
#  'comprehensive': 1,
#  'introduction': 5,
#  'discounted': 1,
#  'pricing': 1,
#  'basic': 5,
#  'onramp': 3,
#  'cover': 2,
#  'essential': 2,
#  'inproduct': 2,
#  'latest': 3,
#  'release': 2,
#  'inperson': 2,
#  'taking': 2,
#  'near': 3,
#  'explore': 8,
#  'self': 3,
#  'paced': 2,
#  'online': 8,
#  'enroll': 4,
#  'excel': 5,
#  'brochure': 3,
#  'quick': 3,
#  'mobile': 7,
#  'campus': 5,
#  'wide': 4,
#  'license': 4,
#  'everyone': 2,
#  'anywhere': 2,
#  'trial': 4,
#  'courseware': 4,
#  'lecture': 8,
#  'material': 4,
#  'ageethagmathworkscom': 4,
#  'question': 5,
#  'u': 12,
#  'central': 6,
#  'user': 4,
#  'inc': 4,
#  'see': 12,
#  'additional': 3,
#  'brand': 2,
#  'respective': 3,
#  'holder': 2,
#  'subscribed': 8,
#  'commercial': 2,
#  'promotion': 2,
#  'privacy': 3,
#  'policy': 2,
#  'private': 2,
#  'âbâ': 2,
#  'wing': 2,
#  'etamin': 2,
#  'prestige': 2,
#  'park': 2,
#  'ii': 32,
#  'marathahalli': 2,
#  'sarjapur': 2,
#  'ring': 2,
#  'road': 3,
#  'bangalore': 2,
#  'karnataka': 2,
#  'tel': 2,
#  'fax': 2,
#  'computational': 5,
#  'credit': 6,
#  'edit': 6,
#  'ive': 4,
#  'shared': 6,
#  'item': 10,
#  'attachment': 5,
#  'stored': 4,
#  'open': 10,
#  'sheet': 24,
#  'ci': 8,
#  'notespdf': 3,
#  'âºï': 1,
#  'nov': 14,
#  'via': 3,
#  'pdf': 2,
#  'within': 1,
#  'httpdrivegooglecom': 1,
#  'lisathung': 6,
#  'patton': 4,
#  'kulpreet': 4,
#  'mail': 12,
#  'msc': 34,
#  'last': 9,
#  'sunday': 4,
#  'july': 7,
#  'instruction': 1,
#  'mentioned': 9,
#  'accepting': 1,
#  'today': 5,
#  'compiler': 6,
#  'made': 2,
#  'ask': 6,
#  'confirm': 5,
#  'entry': 4,
#  'till': 4,
#  'afternoon': 2,
#  'corelation': 3,
#  'matrix': 3,
#  'yaar': 1,
#  'marked': 1,
#  'august': 4,
#  'group': 65,
#  'prolific': 1,
#  'penetration': 1,
#  'daytoday': 1,
#  'life': 2,
#  'concern': 2,
#  'ethical': 1,
#  'use': 5,
#  'legal': 2,
#  'due': 3,
#  'malfunction': 1,
#  'threat': 3,
#  'colloquium': 2,
#  'organized': 6,
#  'httpwwwcmsindiaorgaiforbetterworld': 1,
#  'httpscyberharvardedutopicsethicsandgovernanceai': 1,
#  'httpswwwmediamiteducoursestheethicsandgovernanceofartificialintelligence': 1,
#  'aware': 1,
#  'frontier': 1,
#  'indicate': 1,
#  'importance': 1,
#  'required': 4,
#  'writing': 5,
#  'fcfs': 1,
#  'basis': 6,
#  'dated': 1,
#  'author': 3,
#  'samyak': 7,
#  'sangeeta': 6,
#  'saurabh': 3,
#  'june': 18,
#  'exam': 16,
#  'iv': 4,
#  'mc': 24,
#  'semester': 5,
#  'inout': 2,
#  'sat': 3,
#  'verify': 3,
#  'mark': 8,
#  'discrepency': 1,
#  'roll': 6,
#  'assign': 2,
#  'abhinav': 4,
#  'kumar': 38,
#  'anju': 2,
#  'kumari': 6,
#  'gaur': 2,
#  'anu': 2,
#  'anuradha': 6,
#  'aggarwal': 13,
#  'asha': 2,
#  'singh': 12,
#  'dua': 7,
#  'deepa': 4,
#  'divesh': 3,
#  'bhagat': 2,
#  'ekta': 2,
#  'wahi': 2,
#  'himanshu': 2,
#  'jakhar': 2,
#  'agarwal': 3,
#  'kour': 2,
#  'mayank': 3,
#  'kharbanda': 3,
#  'moni': 2,
#  'tripathi': 2,
#  'monika': 2,
#  'kandari': 2,
#  'naveen': 3,
#  'nitin': 2,
#  'thakur': 2,
#  'preeti': 2,
#  'radhnandani': 4,
#  'prasad': 7,
#  'rishav': 3,
#  'kohli': 2,
#  'rohit': 6,
#  'ronak': 3,
#  'ruchi': 5,
#  'goswami': 3,
#  'ruman': 3,
#  'saleem': 3,
#  'ahuja': 6,
#  'yadav': 9,
#  'bharti': 6,
#  'meena': 4,
#  'smriti': 2,
#  'sharma': 10,
#  'sunil': 6,
#  'swati': 4,
#  'gautam': 3,
#  'tamanna': 2,
#  'tanuj': 4,
#  'rohilla': 6,
#  'tanya': 5,
#  'singhal': 3,
#  'uditi': 3,
#  'kansal': 4,
#  'updesh': 7,
#  'vaishali': 3,
#  'chawla': 2,
#  'vanshika': 2,
#  'kushwaha': 2,
#  'vineet': 2,
#  'karakoti': 2,
#  'atin': 2,
#  'minocha': 2,
#  'aanchal': 4,
#  'gupta': 9,
#  'jatin': 4,
#  'advani': 2,
#  'arora': 3,
#  'naman': 2,
#  'jain': 6,
#  'vrinda': 2,
#  'yacc': 2,
#  'implementation': 2,
#  'tutorial': 1,
#  'found': 1,
#  'quite': 1,
#  'useful': 1,
#  'classmate': 3,
#  'httpswwwyoutubecomwatchvmgimenta': 1,
#  'httpswwwyoutubecomwatchvwefvuovllkm': 1,
#  'internal': 4,
#  'correctionupdation': 1,
#  'allowed': 1,
#  'tmrw': 1,
#  'major': 3,
#  'syllabus': 9,
#  'ever': 1,
#  'done': 2,
#  'good': 6,
#  'morning': 2,
#  'maam': 13,
#  'whether': 1,
#  'chapter': 1,
#  'thank': 7,
#  'pfa': 11,
#  'examination': 1,
#  'network': 4,
#  'programming': 1,
#  'numerical': 3,
#  'computing': 9,
#  'unofficial': 1,
#  'passed': 1,
#  'verbally': 1,
#  'teacher': 2,
#  'consider': 1,
#  'belief': 1,
#  'addition': 1,
#  'subtraction': 1,
#  'topic': 14,
#  'might': 3,
#  'missed': 1,
#  'mentioning': 1,
#  'wise': 2,
#  'rate': 2,
#  'nc': 1,
#  'vipin': 8,
#  'master': 4,
#  'theyre': 2,
#  'manualpdf': 1,
#  'samplepaper': 1,
#  'jan': 5,
#  'shashi': 12,
#  'discrete': 5,
#  'mathematics': 3,
#  'communication': 1,
#  'swiped': 1,
#  'shift': 1,
#  'cd': 5,
#  'election': 1,
#  'hometown': 1,
#  'patwal': 4,
#  'shashicsdugmailcom': 5,
#  'anjali': 4,
#  'bansal': 4,
#  ...}

# %%
freq_terms_class[0]['vasudha']  #check frequency of term 'yeah' in class 0
# Out:
# 23

# %% [markdown]
# ### C. Compute Conditional Probability of each term given class
#
# Cond probability of term t given class c, is computed as:
#
# <b><center>P(t|c) = {(Frequency of term t in class c) + 1} / {( Sum of frequencies of each term in class c) + |V|} </b>
#
# where |V| = size of the vocabulary

# %%
import copy
#Python never implicitly copies objects. dict2 = dict1, both refer to the same object, 
#so when we mutate dic2, all references to it keep referring to the object in its current state and change dict1 as well

cond_prob_class = {}

for ci in range(total_classes):
    #cond_prob_class[ci] = freq_terms_class[ci]
    cond_prob_class[ci] = freq_terms_class[ci].copy()
    
cond_prob_class[0]
# Out:
# {'graph': 13,
#  'average': 1,
#  'comparison': 2,
#  'forwarded': 51,
#  'message': 66,
#  'megha': 65,
#  'surname': 1,
#  'date': 88,
#  'wed': 16,
#  'aug': 26,
#  'pm': 77,
#  'subject': 60,
#  'student': 102,
#  'volunteer': 5,
#  'ducs': 5,
#  'alumnus': 8,
#  'assocation': 2,
#  'dear': 37,
#  'need': 12,
#  'two': 7,
#  'every': 2,
#  'batch': 2,
#  'association': 2,
#  'pls': 12,
#  'provide': 5,
#  'name': 20,
#  'sapna': 14,
#  'varshney': 13,
#  'assistant': 13,
#  'professor': 16,
#  'adhoc': 6,
#  'department': 61,
#  'computer': 66,
#  'science': 72,
#  'university': 75,
#  'delhi': 107,
#  'fwd': 50,
#  'india': 38,
#  'fest': 2,
#  'bring': 6,
#  'world': 8,
#  'vasudha': 23,
#  'bhatnagar': 24,
#  'vasudhabhatnagargmailcom': 15,
#  'sun': 18,
#  'sapnavarshgmailcom': 6,
#  'ronnie': 1,
#  'chakre': 9,
#  'mca': 46,
#  'elective': 4,
#  'form': 31,
#  'ratheepriyankagmailcom': 4,
#  'fri': 16,
#  'dec': 1,
#  'image': 61,
#  'google': 86,
#  'fill': 10,
#  'option': 8,
#  'choose': 1,
#  'algo': 16,
#  'hw': 1,
#  'list': 25,
#  'correctness': 1,
#  'insertion': 2,
#  'sort': 2,
#  'tn': 2,
#  'prove': 6,
#  'tnanb': 1,
#  'constant': 3,
#  'lim': 2,
#  'ninfinity': 2,
#  'fngn': 2,
#  'fn': 2,
#  'ogn': 1,
#  'first': 11,
#  'definition': 2,
#  'c': 12,
#  'thetagn': 1,
#  'log': 3,
#  'nm': 1,
#  'onâ': 1,
#  'however': 1,
#  'large': 3,
#  'small': 3,
#  'logan': 1,
#  'thetalogbn': 1,
#  'base': 1,
#  'doesnt': 1,
#  'matter': 1,
#  'limit': 1,
#  'tntfloorn': 1,
#  'onlogn': 1,
#  'formation': 7,
#  'ieee': 14,
#  'branch': 9,
#  'regard': 32,
#  'office': 23,
#  'priyanka': 7,
#  'rathee': 5,
#  'tue': 25,
#  'himani': 4,
#  'saini': 1,
#  'officecsdugmailcom': 7,
#  'planning': 1,
#  'start': 5,
#  'ie': 4,
#  'provides': 3,
#  'opportunity': 19,
#  'meet': 3,
#  'learn': 22,
#  'fellow': 2,
#  'member': 8,
#  'engage': 1,
#  'professional': 9,
#  'locally': 1,
#  'active': 4,
#  'one': 7,
#  'positive': 1,
#  'element': 1,
#  'college': 6,
#  'offering': 1,
#  'program': 11,
#  'activity': 14,
#  'networking': 1,
#  'faculty': 7,
#  'support': 2,
#  'well': 5,
#  'signature': 1,
#  'least': 4,
#  'needed': 1,
#  'petition': 1,
#  'benefit': 2,
#  'given': 11,
#  'document': 8,
#  'attached': 22,
#  'information': 13,
#  'please': 56,
#  'feel': 3,
#  'free': 19,
#  'contact': 9,
#  'dr': 13,
#  'thanks': 27,
#  'chairperson': 3,
#  'young': 8,
#  'section': 6,
#  'mathematical': 3,
#  'floor': 7,
#  'new': 39,
#  'academic': 11,
#  'block': 6,
#  'find': 12,
#  'linkedin': 13,
#  'wwwlinkedincominpriyankarathee': 3,
#  'dip': 7,
#  'ppt': 21,
#  'updated': 12,
#  'mon': 23,
#  'sundriyal': 41,
#  'wrote': 49,
#  'lot': 4,
#  'roni': 13,
#  'ronniechakregmailcom': 7,
#  'hello': 10,
#  'antivirus': 2,
#  'file': 20,
#  'closure': 1,
#  'prog': 1,
#  'input': 1,
#  'format': 2,
#  'abcdefgh': 1,
#  'fds': 2,
#  'ab': 4,
#  'de': 1,
#  'b': 4,
#  'f': 1,
#  'fg': 1,
#  'h': 7,
#  'doe': 4,
#  'work': 6,
#  'alpha': 1,
#  'value': 2,
#  'invitation': 18,
#  'onload': 6,
#  'hackathon': 7,
#  'vbhatnagarcsduacin': 8,
#  'feb': 11,
#  'du': 21,
#  'cc': 7,
#  'svarshneycsduacin': 1,
#  'forward': 18,
#  'cr': 9,
#  'vb': 5,
#  'contacthackonloadcom': 1,
#  'vbhatnagar': 1,
#  'sent': 5,
#  'tuesday': 6,
#  'february': 15,
#  'team': 18,
#  'behind': 1,
#  'privileged': 1,
#  'invite': 7,
#  'esteemed': 1,
#  'institute': 1,
#  'attend': 2,
#  'event': 6,
#  'intense': 1,
#  'funfilled': 1,
#  'rewarding': 1,
#  'convergence': 2,
#  'talented': 1,
#  'programmer': 1,
#  'designer': 1,
#  'developer': 3,
#  'country': 3,
#  'working': 2,
#  'together': 1,
#  'build': 1,
#  'something': 1,
#  'amazing': 1,
#  'cutting': 1,
#  'edge': 1,
#  'technology': 8,
#  'including': 2,
#  'limited': 4,
#  'artificial': 7,
#  'intelligence': 11,
#  'machine': 15,
#  'learning': 24,
#  'blockchain': 1,
#  'iot': 2,
#  'many': 4,
#  'leveraging': 1,
#  'available': 9,
#  'tool': 3,
#  'apis': 1,
#  'creating': 2,
#  'towards': 2,
#  'common': 5,
#  'goal': 1,
#  'better': 4,
#  'happening': 1,
#  'mysuru': 1,
#  'palace': 1,
#  'city': 9,
#  'march': 8,
#  'website': 3,
#  'httpshackonloadcom': 1,
#  'make': 17,
#  'greater': 1,
#  'request': 9,
#  'share': 10,
#  'get': 23,
#  'utmost': 1,
#  'develop': 2,
#  'skill': 2,
#  'attending': 1,
#  'would': 4,
#  'appreciate': 1,
#  'reach': 2,
#  'institution': 2,
#  'side': 2,
#  'fruitful': 1,
#  'reaction': 1,
#  'participation': 9,
#  'promising': 1,
#  'hand': 1,
#  'grand': 1,
#  'success': 1,
#  'session': 6,
#  'held': 9,
#  'notice': 5,
#  'per': 3,
#  'detail': 14,
#  'following': 10,
#  'schedule': 1,
#  'presentation': 3,
#  'sudhanshu': 1,
#  'vishnoi': 1,
#  'sem': 11,
#  'v': 5,
#  'present': 7,
#  'gsoc': 1,
#  'project': 30,
#  'titled': 2,
#  'implementing': 1,
#  'cross': 2,
#  'reference': 6,
#  'general': 1,
#  'improvement': 6,
#  'respec': 2,
#  'mozilla': 1,
#  'implement': 1,
#  'feature': 1,
#  'fix': 1,
#  'existing': 2,
#  'issue': 3,
#  'improve': 3,
#  'maintainability': 1,
#  'zoo': 1,
#  'âerror': 1,
#  'error': 6,
#  'foundâ': 1,
#  'runnerup': 5,
#  'position': 4,
#  'alexa': 1,
#  'voicebased': 1,
#  'wildlife': 4,
#  'guru': 1,
#  'product': 5,
#  'specie': 1,
#  'trade': 1,
#  'law': 6,
#  'organization': 2,
#  'contacted': 2,
#  'report': 10,
#  'crime': 6,
#  'etc': 5,
#  'day': 16,
#  'monday': 3,
#  'november': 3,
#  'time': 27,
#  'venue': 4,
#  'seminar': 2,
#  'room': 1,
#  'â': 38,
#  'cordially': 3,
#  'invited': 2,
#  'nan': 9,
#  'perlakh': 5,
#  'pca': 7,
#  'year': 76,
#  'normalised': 4,
#  'data': 30,
#  'apr': 23,
#  'abhishek': 16,
#  'sen': 14,
#  'studio': 8,
#  'connected': 6,
#  'account': 41,
#  'hi': 5,
#  'ha': 18,
#  'access': 17,
#  'view': 33,
#  'manage': 4,
#  'drive': 6,
#  'give': 9,
#  'apps': 4,
#  'trust': 2,
#  'review': 3,
#  'remove': 2,
#  'httpsmyaccountgooglecompermissions': 2,
#  'httpssupportgooglecomaccountsanswer': 4,
#  'mean': 2,
#  'connect': 6,
#  'app': 2,
#  'email': 61,
#  'cant': 2,
#  'receive': 2,
#  'reply': 3,
#  'visit': 23,
#  'help': 16,
#  'center': 7,
#  'received': 27,
#  'mandatory': 2,
#  'service': 12,
#  'announcement': 2,
#  'update': 6,
#  'important': 18,
#  'change': 22,
#  'llc': 13,
#  'amphitheatre': 13,
#  'parkway': 13,
#  'mountain': 13,
#  'ca': 13,
#  'usa': 13,
#  'security': 23,
#  'alert': 10,
#  'someone': 2,
#  'signed': 16,
#  'device': 18,
#  'location': 1,
#  'want': 19,
#  'sure': 12,
#  'dont': 6,
#  'recognize': 1,
#  'sign': 1,
#  'password': 4,
#  'right': 2,
#  'away': 1,
#  'unsubscribe': 12,
#  'receiving': 11,
#  'notification': 5,
#  'wa': 19,
#  'intended': 1,
#  'included': 3,
#  'ireland': 2,
#  'unlimited': 2,
#  'company': 3,
#  'wilton': 2,
#  'plaza': 1,
#  'place': 3,
#  'dublin': 1,
#  'registered': 6,
#  'business': 8,
#  'logo': 2,
#  'trademark': 9,
#  'dbms': 2,
#  'practical': 3,
#  'couldnt': 2,
#  'send': 21,
#  'javascript': 1,
#  'added': 2,
#  'link': 20,
#  'code': 4,
#  'inside': 1,
#  'zip': 2,
#  'aos': 6,
#  'issuing': 1,
#  'deptt': 9,
#  'laptop': 4,
#  'summer': 1,
#  'vacation': 1,
#  'class': 33,
#  'requested': 4,
#  'kindly': 7,
#  'inform': 3,
#  'genuinely': 1,
#  'requirement': 4,
#  'projectplacementvacation': 1,
#  'lab': 2,
#  'submit': 1,
#  'application': 7,
#  'plain': 1,
#  'paper': 9,
#  'genuine': 1,
#  'reason': 5,
#  'addressing': 1,
#  'hod': 2,
#  'devki': 1,
#  'rawat': 1,
#  'incharge': 1,
#  'ext': 1,
#  'numpy': 1,
#  'ayush': 5,
#  'chhavi': 3,
#  'remcs': 1,
#  'test': 11,
#  'div': 9,
#  'dirltrok': 1,
#  'let': 25,
#  'know': 28,
#  'shortly': 2,
#  'studentsbr': 1,
#  'divdiv': 16,
#  'dirltrbr': 11,
#  'redmi': 5,
#  'may': 47,
#  'wrotebr': 1,
#  'typeattributionblockquote': 3,
#  'classquote': 3,
#  'stylemargin': 3,
#  'ccc': 3,
#  'dirautogood': 1,
#  'evening': 7,
#  'dirautopfb': 1,
#  'testâ': 1,
#  'dirautodiv': 1,
#  'dirautobrdivdiv': 3,
#  'radhnandanidivdiv': 1,
#  'sangeetadivdiv': 1,
#  'updeshdivdiv': 1,
#  'ruchidivdiv': 1,
#  'saurav': 9,
#  'meenadivdiv': 1,
#  'deepadivdiv': 1,
#  'absent': 2,
#  'assignment': 10,
#  'possible': 9,
#  'another': 2,
#  'assignmentdivdiv': 1,
#  'dirautothank': 1,
#  'youâ': 1,
#  'dirautomegha': 1,
#  'sundriyaldivdivdiv': 1,
#  'blockquotediv': 3,
#  'midsemester': 2,
#  'break': 2,
#  'thru': 2,
#  'vbducsgmailcom': 7,
#  'sep': 11,
#  'krishna': 7,
#  'ia': 4,
#  'discrepancy': 3,
#  'tomorrow': 2,
#  'final': 13,
#  'msccs': 7,
#  'iii': 21,
#  'minor': 20,
#  'preference': 15,
#  'jul': 1,
#  'sai': 1,
#  'window': 5,
#  'youre': 7,
#  'getting': 10,
#  'check': 21,
#  'naac': 6,
#  'peer': 10,
#  'meeting': 3,
#  'greeting': 4,
#  'behalf': 1,
#  'offer': 4,
#  'felicitation': 1,
#  'part': 3,
#  'distinguished': 1,
#  'heartening': 1,
#  'note': 13,
#  'ranked': 4,
#  'centre': 3,
#  'ranking': 2,
#  'cwur': 1,
#  'among': 5,
#  'q': 3,
#  'national': 2,
#  'level': 1,
#  'also': 22,
#  'top': 5,
#  'brics': 1,
#  'region': 2,
#  'happy': 1,
#  'based': 8,
#  'submitted': 1,
#  'feedback': 1,
#  'assessment': 5,
#  'accreditation': 3,
#  'council': 2,
#  'decided': 1,
#  'octoberâ': 1,
#  'since': 5,
#  'expected': 1,
#  'strengthen': 1,
#  'coveted': 1,
#  'cherished': 1,
#  'duty': 1,
#  'contribute': 1,
#  'impending': 1,
#  'scheduled': 1,
#  'convention': 2,
#  'hall': 3,
#  'vice': 3,
#  'regal': 1,
#  'lodge': 2,
#  'advised': 2,
#  'carry': 1,
#  'icard': 1,
#  'verification': 4,
#  'understanding': 2,
#  'component': 1,
#  'glad': 2,
#  'mention': 4,
#  'response': 4,
#  'earlier': 2,
#  'survey': 1,
#  'regarding': 5,
#  'âoverall': 1,
#  'experienceâ': 1,
#  'always': 1,
#  'remained': 1,
#  'âvery': 1,
#  'goodâ': 1,
#  'reflects': 1,
#  'overall': 1,
#  'quality': 1,
#  'research': 2,
#  'programme': 1,
#  'offered': 1,
#  'valuable': 1,
#  'contribution': 1,
#  'ensure': 2,
#  'completes': 1,
#  'exercise': 1,
#  'successfully': 1,
#  'wishing': 1,
#  'best': 16,
#  'future': 2,
#  'wish': 6,
#  'dean': 9,
#  'scribe': 23,
#  'thing': 4,
#  'proper': 1,
#  'indentation': 1,
#  'everything': 1,
#  'left': 7,
#  'able': 4,
#  'put': 4,
#  'equation': 2,
#  'lhopital': 1,
#  'aligned': 1,
#  'coming': 1,
#  'internet': 1,
#  'tick': 1,
#  'latex': 1,
#  'table': 8,
#  'unemployment': 1,
#  'dataset': 2,
#  'matlab': 51,
#  'simulink': 34,
#  'resource': 9,
#  'academia': 6,
#  'thu': 9,
#  'mar': 13,
#  'fyi': 4,
#  'homepage': 5,
#  'peopleduacinvbhatnagar': 5,
#  'anand': 4,
#  'geethagovindan': 4,
#  'anandgeethagovindangomathworkscom': 2,
#  'mathworks': 16,
#  'certification': 4,
#  'ai': 25,
#  'robotics': 4,
#  'arena': 3,
#  'upcoming': 6,
#  'webinars': 6,
#  'training': 14,
#  'web': 13,
#  'page': 5,
#  'click': 10,
#  'career': 2,
#  'establishes': 1,
#  'standard': 1,
#  'excellence': 1,
#  'demonstrates': 1,
#  'proficiency': 1,
#  'customer': 1,
#  'industry': 2,
#  'employer': 1,
#  'featured': 2,
#  'everywhere': 1,
#  'powering': 1,
#  'like': 8,
#  'smart': 1,
#  'translation': 1,
#  'automated': 4,
#  'driving': 4,
#  'giving': 1,
#  'engineer': 1,
#  'scientist': 4,
#  'set': 3,
#  'technique': 2,
#  'tackling': 1,
#  'task': 4,
#  'way': 6,
#  'download': 8,
#  'ebook': 4,
#  'gartner': 3,
#  'recognized': 2,
#  'visionary': 2,
#  'magic': 2,
#  'quadrant': 2,
#  'january': 5,
#  'platform': 1,
#  'read': 3,
#  'blog': 1,
#  'modeling': 3,
#  'pneumatic': 3,
#  'robot': 2,
#  'actuator': 2,
#  'join': 4,
#  'veer': 1,
#  'alakshendra': 1,
#  'maitreyee': 1,
#  'mordekar': 1,
#  'discus': 2,
#  'simulation': 3,
#  'system': 7,
#  'relevant': 1,
#  'competition': 5,
#  'robocon': 1,
#  'watch': 4,
#  'video': 5,
#  'complimentary': 3,
#  'software': 3,
#  'supra': 3,
#  'saeindia': 3,
#  'participating': 4,
#  'developing': 4,
#  'dcdc': 2,
#  'converter': 4,
#  'control': 4,
#  'register': 23,
#  'predictive': 3,
#  'maintenance': 3,
#  'prognostic': 3,
#  'case': 7,
#  'study': 11,
#  'started': 4,
#  'vehicle': 5,
#  'dynamic': 1,
#  'blockset': 1,
#  'vdbs': 1,
#  'design': 11,
#  'combinatorial': 3,
#  'sequential': 1,
#  'logic': 1,
#  'using': 5,
#  'state': 3,
#  'stateflow': 1,
#  'classroom': 1,
#  'ready': 2,
#  'arduino': 1,
#  'engineering': 9,
#  'kit': 1,
#  'full': 2,
#  'demand': 6,
#  'deep': 7,
#  'selfpaced': 3,
#  'course': 8,
#  'comprehensive': 1,
#  'introduction': 5,
#  'discounted': 1,
#  'pricing': 1,
#  'basic': 5,
#  'onramp': 3,
#  'cover': 2,
#  'essential': 2,
#  'inproduct': 2,
#  'latest': 3,
#  'release': 2,
#  'inperson': 2,
#  'taking': 2,
#  'near': 3,
#  'explore': 8,
#  'self': 3,
#  'paced': 2,
#  'online': 8,
#  'enroll': 4,
#  'excel': 5,
#  'brochure': 3,
#  'quick': 3,
#  'mobile': 7,
#  'campus': 5,
#  'wide': 4,
#  'license': 4,
#  'everyone': 2,
#  'anywhere': 2,
#  'trial': 4,
#  'courseware': 4,
#  'lecture': 8,
#  'material': 4,
#  'ageethagmathworkscom': 4,
#  'question': 5,
#  'u': 12,
#  'central': 6,
#  'user': 4,
#  'inc': 4,
#  'see': 12,
#  'additional': 3,
#  'brand': 2,
#  'respective': 3,
#  'holder': 2,
#  'subscribed': 8,
#  'commercial': 2,
#  'promotion': 2,
#  'privacy': 3,
#  'policy': 2,
#  'private': 2,
#  'âbâ': 2,
#  'wing': 2,
#  'etamin': 2,
#  'prestige': 2,
#  'park': 2,
#  'ii': 32,
#  'marathahalli': 2,
#  'sarjapur': 2,
#  'ring': 2,
#  'road': 3,
#  'bangalore': 2,
#  'karnataka': 2,
#  'tel': 2,
#  'fax': 2,
#  'computational': 5,
#  'credit': 6,
#  'edit': 6,
#  'ive': 4,
#  'shared': 6,
#  'item': 10,
#  'attachment': 5,
#  'stored': 4,
#  'open': 10,
#  'sheet': 24,
#  'ci': 8,
#  'notespdf': 3,
#  'âºï': 1,
#  'nov': 14,
#  'via': 3,
#  'pdf': 2,
#  'within': 1,
#  'httpdrivegooglecom': 1,
#  'lisathung': 6,
#  'patton': 4,
#  'kulpreet': 4,
#  'mail': 12,
#  'msc': 34,
#  'last': 9,
#  'sunday': 4,
#  'july': 7,
#  'instruction': 1,
#  'mentioned': 9,
#  'accepting': 1,
#  'today': 5,
#  'compiler': 6,
#  'made': 2,
#  'ask': 6,
#  'confirm': 5,
#  'entry': 4,
#  'till': 4,
#  'afternoon': 2,
#  'corelation': 3,
#  'matrix': 3,
#  'yaar': 1,
#  'marked': 1,
#  'august': 4,
#  'group': 65,
#  'prolific': 1,
#  'penetration': 1,
#  'daytoday': 1,
#  'life': 2,
#  'concern': 2,
#  'ethical': 1,
#  'use': 5,
#  'legal': 2,
#  'due': 3,
#  'malfunction': 1,
#  'threat': 3,
#  'colloquium': 2,
#  'organized': 6,
#  'httpwwwcmsindiaorgaiforbetterworld': 1,
#  'httpscyberharvardedutopicsethicsandgovernanceai': 1,
#  'httpswwwmediamiteducoursestheethicsandgovernanceofartificialintelligence': 1,
#  'aware': 1,
#  'frontier': 1,
#  'indicate': 1,
#  'importance': 1,
#  'required': 4,
#  'writing': 5,
#  'fcfs': 1,
#  'basis': 6,
#  'dated': 1,
#  'author': 3,
#  'samyak': 7,
#  'sangeeta': 6,
#  'saurabh': 3,
#  'june': 18,
#  'exam': 16,
#  'iv': 4,
#  'mc': 24,
#  'semester': 5,
#  'inout': 2,
#  'sat': 3,
#  'verify': 3,
#  'mark': 8,
#  'discrepency': 1,
#  'roll': 6,
#  'assign': 2,
#  'abhinav': 4,
#  'kumar': 38,
#  'anju': 2,
#  'kumari': 6,
#  'gaur': 2,
#  'anu': 2,
#  'anuradha': 6,
#  'aggarwal': 13,
#  'asha': 2,
#  'singh': 12,
#  'dua': 7,
#  'deepa': 4,
#  'divesh': 3,
#  'bhagat': 2,
#  'ekta': 2,
#  'wahi': 2,
#  'himanshu': 2,
#  'jakhar': 2,
#  'agarwal': 3,
#  'kour': 2,
#  'mayank': 3,
#  'kharbanda': 3,
#  'moni': 2,
#  'tripathi': 2,
#  'monika': 2,
#  'kandari': 2,
#  'naveen': 3,
#  'nitin': 2,
#  'thakur': 2,
#  'preeti': 2,
#  'radhnandani': 4,
#  'prasad': 7,
#  'rishav': 3,
#  'kohli': 2,
#  'rohit': 6,
#  'ronak': 3,
#  'ruchi': 5,
#  'goswami': 3,
#  'ruman': 3,
#  'saleem': 3,
#  'ahuja': 6,
#  'yadav': 9,
#  'bharti': 6,
#  'meena': 4,
#  'smriti': 2,
#  'sharma': 10,
#  'sunil': 6,
#  'swati': 4,
#  'gautam': 3,
#  'tamanna': 2,
#  'tanuj': 4,
#  'rohilla': 6,
#  'tanya': 5,
#  'singhal': 3,
#  'uditi': 3,
#  'kansal': 4,
#  'updesh': 7,
#  'vaishali': 3,
#  'chawla': 2,
#  'vanshika': 2,
#  'kushwaha': 2,
#  'vineet': 2,
#  'karakoti': 2,
#  'atin': 2,
#  'minocha': 2,
#  'aanchal': 4,
#  'gupta': 9,
#  'jatin': 4,
#  'advani': 2,
#  'arora': 3,
#  'naman': 2,
#  'jain': 6,
#  'vrinda': 2,
#  'yacc': 2,
#  'implementation': 2,
#  'tutorial': 1,
#  'found': 1,
#  'quite': 1,
#  'useful': 1,
#  'classmate': 3,
#  'httpswwwyoutubecomwatchvmgimenta': 1,
#  'httpswwwyoutubecomwatchvwefvuovllkm': 1,
#  'internal': 4,
#  'correctionupdation': 1,
#  'allowed': 1,
#  'tmrw': 1,
#  'major': 3,
#  'syllabus': 9,
#  'ever': 1,
#  'done': 2,
#  'good': 6,
#  'morning': 2,
#  'maam': 13,
#  'whether': 1,
#  'chapter': 1,
#  'thank': 7,
#  'pfa': 11,
#  'examination': 1,
#  'network': 4,
#  'programming': 1,
#  'numerical': 3,
#  'computing': 9,
#  'unofficial': 1,
#  'passed': 1,
#  'verbally': 1,
#  'teacher': 2,
#  'consider': 1,
#  'belief': 1,
#  'addition': 1,
#  'subtraction': 1,
#  'topic': 14,
#  'might': 3,
#  'missed': 1,
#  'mentioning': 1,
#  'wise': 2,
#  'rate': 2,
#  'nc': 1,
#  'vipin': 8,
#  'master': 4,
#  'theyre': 2,
#  'manualpdf': 1,
#  'samplepaper': 1,
#  'jan': 5,
#  'shashi': 12,
#  'discrete': 5,
#  'mathematics': 3,
#  'communication': 1,
#  'swiped': 1,
#  'shift': 1,
#  'cd': 5,
#  'election': 1,
#  'hometown': 1,
#  'patwal': 4,
#  'shashicsdugmailcom': 5,
#  'anjali': 4,
#  'bansal': 4,
#  ...}

# %%
len(vocab)
# Out:
# 7686

# %%
#denominator remains same for all the terms in same class. 
#denom for class 0

denom = sum(freq_terms_class[0].values())+len(vocab)
denom
# Out:
# 17255

# %%
# for each term in the class, calculate cond prob. this is to be done for all the classes.

#iterate through each class one by one
for ci in range(total_classes):
    # compute cond_prob for each term in this class
    denom = sum(freq_terms_class[ci].values())+len(vocab)
    
    # go to each term in this class and compute its cond_prob within this class
    for term in cond_prob_class[ci]:
        freq_term = freq_terms_class[ci][term]
        cond_prob_class[ci][term] = (freq_term+1)/denom

cond_prob_class[0]   #check cond prob for for each term, given class 0
# Out:
# {'graph': 0.0008113590263691683,
#  'average': 0.00011590843233845262,
#  'comparison': 0.00017386264850767892,
#  'forwarded': 0.003013619240799768,
#  'message': 0.003882932483338163,
#  'megha': 0.0038249782671689364,
#  'surname': 0.00011590843233845262,
#  'date': 0.005157925239061141,
#  'wed': 0.0009852216748768472,
#  'aug': 0.0015647638365691105,
#  'pm': 0.004520428861199652,
#  'subject': 0.003535207186322805,
#  'student': 0.00596928426543031,
#  'volunteer': 0.00034772529701535785,
#  'ducs': 0.00034772529701535785,
#  'alumnus': 0.0005215879455230368,
#  'assocation': 0.00017386264850767892,
#  'dear': 0.0022022602144305997,
#  'need': 0.000753404810199942,
#  'two': 0.0004636337293538105,
#  'every': 0.00017386264850767892,
#  'batch': 0.00017386264850767892,
#  'association': 0.00017386264850767892,
#  'pls': 0.000753404810199942,
#  'provide': 0.00034772529701535785,
#  'name': 0.0012170385395537525,
#  'sapna': 0.0008693132425383947,
#  'varshney': 0.0008113590263691683,
#  'assistant': 0.0008113590263691683,
#  'professor': 0.0009852216748768472,
#  'adhoc': 0.00040567951318458417,
#  'department': 0.003593161402492031,
#  'computer': 0.003882932483338163,
#  'science': 0.004230657780353521,
#  'university': 0.0044045204288611995,
#  'delhi': 0.006259055346276442,
#  'fwd': 0.002955665024630542,
#  'india': 0.002260214430599826,
#  'fest': 0.00017386264850767892,
#  'bring': 0.00040567951318458417,
#  'world': 0.0005215879455230368,
#  'vasudha': 0.0013909011880614314,
#  'bhatnagar': 0.0014488554042306578,
#  'vasudhabhatnagargmailcom': 0.000927267458707621,
#  'sun': 0.0011011301072152999,
#  'sapnavarshgmailcom': 0.00040567951318458417,
#  'ronnie': 0.00011590843233845262,
#  'chakre': 0.0005795421616922632,
#  'mca': 0.0027238481599536368,
#  'elective': 0.0002897710808461316,
#  'form': 0.001854534917415242,
#  'ratheepriyankagmailcom': 0.0002897710808461316,
#  'fri': 0.0009852216748768472,
#  'dec': 0.00011590843233845262,
#  'image': 0.003593161402492031,
#  'google': 0.005042016806722689,
#  'fill': 0.0006374963778614895,
#  'option': 0.0005215879455230368,
#  'choose': 0.00011590843233845262,
#  'algo': 0.0009852216748768472,
#  'hw': 0.00011590843233845262,
#  'list': 0.001506809620399884,
#  'correctness': 0.00011590843233845262,
#  'insertion': 0.00017386264850767892,
#  'sort': 0.00017386264850767892,
#  'tn': 0.00017386264850767892,
#  'prove': 0.00040567951318458417,
#  'tnanb': 0.00011590843233845262,
#  'constant': 0.00023181686467690525,
#  'lim': 0.00017386264850767892,
#  'ninfinity': 0.00017386264850767892,
#  'fngn': 0.00017386264850767892,
#  'fn': 0.00017386264850767892,
#  'ogn': 0.00011590843233845262,
#  'first': 0.0006954505940307157,
#  'definition': 0.00017386264850767892,
#  'c': 0.000753404810199942,
#  'thetagn': 0.00011590843233845262,
#  'log': 0.00023181686467690525,
#  'nm': 0.00011590843233845262,
#  'onâ': 0.00011590843233845262,
#  'however': 0.00011590843233845262,
#  'large': 0.00023181686467690525,
#  'small': 0.00023181686467690525,
#  'logan': 0.00011590843233845262,
#  'thetalogbn': 0.00011590843233845262,
#  'base': 0.00011590843233845262,
#  'doesnt': 0.00011590843233845262,
#  'matter': 0.00011590843233845262,
#  'limit': 0.00011590843233845262,
#  'tntfloorn': 0.00011590843233845262,
#  'onlogn': 0.00011590843233845262,
#  'formation': 0.0004636337293538105,
#  'ieee': 0.0008693132425383947,
#  'branch': 0.0005795421616922632,
#  'regard': 0.0019124891335844682,
#  'office': 0.0013909011880614314,
#  'priyanka': 0.0004636337293538105,
#  'rathee': 0.00034772529701535785,
#  'tue': 0.001506809620399884,
#  'himani': 0.0002897710808461316,
#  'saini': 0.00011590843233845262,
#  'officecsdugmailcom': 0.0004636337293538105,
#  'planning': 0.00011590843233845262,
#  'start': 0.00034772529701535785,
#  'ie': 0.0002897710808461316,
#  'provides': 0.00023181686467690525,
#  'opportunity': 0.0011590843233845263,
#  'meet': 0.00023181686467690525,
#  'learn': 0.0013329469718922052,
#  'fellow': 0.00017386264850767892,
#  'member': 0.0005215879455230368,
#  'engage': 0.00011590843233845262,
#  'professional': 0.0005795421616922632,
#  'locally': 0.00011590843233845262,
#  'active': 0.0002897710808461316,
#  'one': 0.0004636337293538105,
#  'positive': 0.00011590843233845262,
#  'element': 0.00011590843233845262,
#  'college': 0.00040567951318458417,
#  'offering': 0.00011590843233845262,
#  'program': 0.0006954505940307157,
#  'activity': 0.0008693132425383947,
#  'networking': 0.00011590843233845262,
#  'faculty': 0.0004636337293538105,
#  'support': 0.00017386264850767892,
#  'well': 0.00034772529701535785,
#  'signature': 0.00011590843233845262,
#  'least': 0.0002897710808461316,
#  'needed': 0.00011590843233845262,
#  'petition': 0.00011590843233845262,
#  'benefit': 0.00017386264850767892,
#  'given': 0.0006954505940307157,
#  'document': 0.0005215879455230368,
#  'attached': 0.0013329469718922052,
#  'information': 0.0008113590263691683,
#  'please': 0.0033033903216459,
#  'feel': 0.00023181686467690525,
#  'free': 0.0011590843233845263,
#  'contact': 0.0005795421616922632,
#  'dr': 0.0008113590263691683,
#  'thanks': 0.0016227180527383367,
#  'chairperson': 0.00023181686467690525,
#  'young': 0.0005215879455230368,
#  'section': 0.00040567951318458417,
#  'mathematical': 0.00023181686467690525,
#  'floor': 0.0004636337293538105,
#  'new': 0.0023181686467690526,
#  'academic': 0.0006954505940307157,
#  'block': 0.00040567951318458417,
#  'find': 0.000753404810199942,
#  'linkedin': 0.0008113590263691683,
#  'wwwlinkedincominpriyankarathee': 0.00023181686467690525,
#  'dip': 0.0004636337293538105,
#  'ppt': 0.001274992755722979,
#  'updated': 0.000753404810199942,
#  'mon': 0.0013909011880614314,
#  'sundriyal': 0.002434077079107505,
#  'wrote': 0.0028977108084613156,
#  'lot': 0.0002897710808461316,
#  'roni': 0.0008113590263691683,
#  'ronniechakregmailcom': 0.0004636337293538105,
#  'hello': 0.0006374963778614895,
#  'antivirus': 0.00017386264850767892,
#  'file': 0.0012170385395537525,
#  'closure': 0.00011590843233845262,
#  'prog': 0.00011590843233845262,
#  'input': 0.00011590843233845262,
#  'format': 0.00017386264850767892,
#  'abcdefgh': 0.00011590843233845262,
#  'fds': 0.00017386264850767892,
#  'ab': 0.0002897710808461316,
#  'de': 0.00011590843233845262,
#  'b': 0.0002897710808461316,
#  'f': 0.00011590843233845262,
#  'fg': 0.00011590843233845262,
#  'h': 0.0004636337293538105,
#  'doe': 0.0002897710808461316,
#  'work': 0.00040567951318458417,
#  'alpha': 0.00011590843233845262,
#  'value': 0.00017386264850767892,
#  'invitation': 0.0011011301072152999,
#  'onload': 0.00040567951318458417,
#  'hackathon': 0.0004636337293538105,
#  'vbhatnagarcsduacin': 0.0005215879455230368,
#  'feb': 0.0006954505940307157,
#  'du': 0.001274992755722979,
#  'cc': 0.0004636337293538105,
#  'svarshneycsduacin': 0.00011590843233845262,
#  'forward': 0.0011011301072152999,
#  'cr': 0.0005795421616922632,
#  'vb': 0.00034772529701535785,
#  'contacthackonloadcom': 0.00011590843233845262,
#  'vbhatnagar': 0.00011590843233845262,
#  'sent': 0.00034772529701535785,
#  'tuesday': 0.00040567951318458417,
#  'february': 0.000927267458707621,
#  'team': 0.0011011301072152999,
#  'behind': 0.00011590843233845262,
#  'privileged': 0.00011590843233845262,
#  'invite': 0.0004636337293538105,
#  'esteemed': 0.00011590843233845262,
#  'institute': 0.00011590843233845262,
#  'attend': 0.00017386264850767892,
#  'event': 0.00040567951318458417,
#  'intense': 0.00011590843233845262,
#  'funfilled': 0.00011590843233845262,
#  'rewarding': 0.00011590843233845262,
#  'convergence': 0.00017386264850767892,
#  'talented': 0.00011590843233845262,
#  'programmer': 0.00011590843233845262,
#  'designer': 0.00011590843233845262,
#  'developer': 0.00023181686467690525,
#  'country': 0.00023181686467690525,
#  'working': 0.00017386264850767892,
#  'together': 0.00011590843233845262,
#  'build': 0.00011590843233845262,
#  'something': 0.00011590843233845262,
#  'amazing': 0.00011590843233845262,
#  'cutting': 0.00011590843233845262,
#  'edge': 0.00011590843233845262,
#  'technology': 0.0005215879455230368,
#  'including': 0.00017386264850767892,
#  'limited': 0.0002897710808461316,
#  'artificial': 0.0004636337293538105,
#  'intelligence': 0.0006954505940307157,
#  'machine': 0.000927267458707621,
#  'learning': 0.0014488554042306578,
#  'blockchain': 0.00011590843233845262,
#  'iot': 0.00017386264850767892,
#  'many': 0.0002897710808461316,
#  'leveraging': 0.00011590843233845262,
#  'available': 0.0005795421616922632,
#  'tool': 0.00023181686467690525,
#  'apis': 0.00011590843233845262,
#  'creating': 0.00017386264850767892,
#  'towards': 0.00017386264850767892,
#  'common': 0.00034772529701535785,
#  'goal': 0.00011590843233845262,
#  'better': 0.0002897710808461316,
#  'happening': 0.00011590843233845262,
#  'mysuru': 0.00011590843233845262,
#  'palace': 0.00011590843233845262,
#  'city': 0.0005795421616922632,
#  'march': 0.0005215879455230368,
#  'website': 0.00023181686467690525,
#  'httpshackonloadcom': 0.00011590843233845262,
#  'make': 0.0010431758910460736,
#  'greater': 0.00011590843233845262,
#  'request': 0.0005795421616922632,
#  'share': 0.0006374963778614895,
#  'get': 0.0013909011880614314,
#  'utmost': 0.00011590843233845262,
#  'develop': 0.00017386264850767892,
#  'skill': 0.00017386264850767892,
#  'attending': 0.00011590843233845262,
#  'would': 0.0002897710808461316,
#  'appreciate': 0.00011590843233845262,
#  'reach': 0.00017386264850767892,
#  'institution': 0.00017386264850767892,
#  'side': 0.00017386264850767892,
#  'fruitful': 0.00011590843233845262,
#  'reaction': 0.00011590843233845262,
#  'participation': 0.0005795421616922632,
#  'promising': 0.00011590843233845262,
#  'hand': 0.00011590843233845262,
#  'grand': 0.00011590843233845262,
#  'success': 0.00011590843233845262,
#  'session': 0.00040567951318458417,
#  'held': 0.0005795421616922632,
#  'notice': 0.00034772529701535785,
#  'per': 0.00023181686467690525,
#  'detail': 0.0008693132425383947,
#  'following': 0.0006374963778614895,
#  'schedule': 0.00011590843233845262,
#  'presentation': 0.00023181686467690525,
#  'sudhanshu': 0.00011590843233845262,
#  'vishnoi': 0.00011590843233845262,
#  'sem': 0.0006954505940307157,
#  'v': 0.00034772529701535785,
#  'present': 0.0004636337293538105,
#  'gsoc': 0.00011590843233845262,
#  'project': 0.0017965807012460156,
#  'titled': 0.00017386264850767892,
#  'implementing': 0.00011590843233845262,
#  'cross': 0.00017386264850767892,
#  'reference': 0.00040567951318458417,
#  'general': 0.00011590843233845262,
#  'improvement': 0.00040567951318458417,
#  'respec': 0.00017386264850767892,
#  'mozilla': 0.00011590843233845262,
#  'implement': 0.00011590843233845262,
#  'feature': 0.00011590843233845262,
#  'fix': 0.00011590843233845262,
#  'existing': 0.00017386264850767892,
#  'issue': 0.00023181686467690525,
#  'improve': 0.00023181686467690525,
#  'maintainability': 0.00011590843233845262,
#  'zoo': 0.00011590843233845262,
#  'âerror': 0.00011590843233845262,
#  'error': 0.00040567951318458417,
#  'foundâ': 0.00011590843233845262,
#  'runnerup': 0.00034772529701535785,
#  'position': 0.0002897710808461316,
#  'alexa': 0.00011590843233845262,
#  'voicebased': 0.00011590843233845262,
#  'wildlife': 0.0002897710808461316,
#  'guru': 0.00011590843233845262,
#  'product': 0.00034772529701535785,
#  'specie': 0.00011590843233845262,
#  'trade': 0.00011590843233845262,
#  'law': 0.00040567951318458417,
#  'organization': 0.00017386264850767892,
#  'contacted': 0.00017386264850767892,
#  'report': 0.0006374963778614895,
#  'crime': 0.00040567951318458417,
#  'etc': 0.00034772529701535785,
#  'day': 0.0009852216748768472,
#  'monday': 0.00023181686467690525,
#  'november': 0.00023181686467690525,
#  'time': 0.0016227180527383367,
#  'venue': 0.0002897710808461316,
#  'seminar': 0.00017386264850767892,
#  'room': 0.00011590843233845262,
#  'â': 0.002260214430599826,
#  'cordially': 0.00023181686467690525,
#  'invited': 0.00017386264850767892,
#  'nan': 0.0005795421616922632,
#  'perlakh': 0.00034772529701535785,
#  'pca': 0.0004636337293538105,
#  'year': 0.004462474645030426,
#  'normalised': 0.0002897710808461316,
#  'data': 0.0017965807012460156,
#  'apr': 0.0013909011880614314,
#  'abhishek': 0.0009852216748768472,
#  'sen': 0.0008693132425383947,
#  'studio': 0.0005215879455230368,
#  'connected': 0.00040567951318458417,
#  'account': 0.002434077079107505,
#  'hi': 0.00034772529701535785,
#  'ha': 0.0011011301072152999,
#  'access': 0.0010431758910460736,
#  'view': 0.0019704433497536944,
#  'manage': 0.0002897710808461316,
#  'drive': 0.00040567951318458417,
#  'give': 0.0005795421616922632,
#  'apps': 0.0002897710808461316,
#  'trust': 0.00017386264850767892,
#  'review': 0.00023181686467690525,
#  'remove': 0.00017386264850767892,
#  'httpsmyaccountgooglecompermissions': 0.00017386264850767892,
#  'httpssupportgooglecomaccountsanswer': 0.0002897710808461316,
#  'mean': 0.00017386264850767892,
#  'connect': 0.00040567951318458417,
#  'app': 0.00017386264850767892,
#  'email': 0.003593161402492031,
#  'cant': 0.00017386264850767892,
#  'receive': 0.00017386264850767892,
#  'reply': 0.00023181686467690525,
#  'visit': 0.0013909011880614314,
#  'help': 0.0009852216748768472,
#  'center': 0.0004636337293538105,
#  'received': 0.0016227180527383367,
#  'mandatory': 0.00017386264850767892,
#  'service': 0.000753404810199942,
#  'announcement': 0.00017386264850767892,
#  'update': 0.00040567951318458417,
#  'important': 0.0011011301072152999,
#  'change': 0.0013329469718922052,
#  'llc': 0.0008113590263691683,
#  'amphitheatre': 0.0008113590263691683,
#  'parkway': 0.0008113590263691683,
#  'mountain': 0.0008113590263691683,
#  'ca': 0.0008113590263691683,
#  'usa': 0.0008113590263691683,
#  'security': 0.0013909011880614314,
#  'alert': 0.0006374963778614895,
#  'someone': 0.00017386264850767892,
#  'signed': 0.0009852216748768472,
#  'device': 0.0011011301072152999,
#  'location': 0.00011590843233845262,
#  'want': 0.0011590843233845263,
#  'sure': 0.000753404810199942,
#  'dont': 0.00040567951318458417,
#  'recognize': 0.00011590843233845262,
#  'sign': 0.00011590843233845262,
#  'password': 0.0002897710808461316,
#  'right': 0.00017386264850767892,
#  'away': 0.00011590843233845262,
#  'unsubscribe': 0.000753404810199942,
#  'receiving': 0.0006954505940307157,
#  'notification': 0.00034772529701535785,
#  'wa': 0.0011590843233845263,
#  'intended': 0.00011590843233845262,
#  'included': 0.00023181686467690525,
#  'ireland': 0.00017386264850767892,
#  'unlimited': 0.00017386264850767892,
#  'company': 0.00023181686467690525,
#  'wilton': 0.00017386264850767892,
#  'plaza': 0.00011590843233845262,
#  'place': 0.00023181686467690525,
#  'dublin': 0.00011590843233845262,
#  'registered': 0.00040567951318458417,
#  'business': 0.0005215879455230368,
#  'logo': 0.00017386264850767892,
#  'trademark': 0.0005795421616922632,
#  'dbms': 0.00017386264850767892,
#  'practical': 0.00023181686467690525,
#  'couldnt': 0.00017386264850767892,
#  'send': 0.001274992755722979,
#  'javascript': 0.00011590843233845262,
#  'added': 0.00017386264850767892,
#  'link': 0.0012170385395537525,
#  'code': 0.0002897710808461316,
#  'inside': 0.00011590843233845262,
#  'zip': 0.00017386264850767892,
#  'aos': 0.00040567951318458417,
#  'issuing': 0.00011590843233845262,
#  'deptt': 0.0005795421616922632,
#  'laptop': 0.0002897710808461316,
#  'summer': 0.00011590843233845262,
#  'vacation': 0.00011590843233845262,
#  'class': 0.0019704433497536944,
#  'requested': 0.0002897710808461316,
#  'kindly': 0.0004636337293538105,
#  'inform': 0.00023181686467690525,
#  'genuinely': 0.00011590843233845262,
#  'requirement': 0.0002897710808461316,
#  'projectplacementvacation': 0.00011590843233845262,
#  'lab': 0.00017386264850767892,
#  'submit': 0.00011590843233845262,
#  'application': 0.0004636337293538105,
#  'plain': 0.00011590843233845262,
#  'paper': 0.0005795421616922632,
#  'genuine': 0.00011590843233845262,
#  'reason': 0.00034772529701535785,
#  'addressing': 0.00011590843233845262,
#  'hod': 0.00017386264850767892,
#  'devki': 0.00011590843233845262,
#  'rawat': 0.00011590843233845262,
#  'incharge': 0.00011590843233845262,
#  'ext': 0.00011590843233845262,
#  'numpy': 0.00011590843233845262,
#  'ayush': 0.00034772529701535785,
#  'chhavi': 0.00023181686467690525,
#  'remcs': 0.00011590843233845262,
#  'test': 0.0006954505940307157,
#  'div': 0.0005795421616922632,
#  'dirltrok': 0.00011590843233845262,
#  'let': 0.001506809620399884,
#  'know': 0.0016806722689075631,
#  'shortly': 0.00017386264850767892,
#  'studentsbr': 0.00011590843233845262,
#  'divdiv': 0.0009852216748768472,
#  'dirltrbr': 0.0006954505940307157,
#  'redmi': 0.00034772529701535785,
#  'may': 0.0027818023761228628,
#  'wrotebr': 0.00011590843233845262,
#  'typeattributionblockquote': 0.00023181686467690525,
#  'classquote': 0.00023181686467690525,
#  'stylemargin': 0.00023181686467690525,
#  'ccc': 0.00023181686467690525,
#  'dirautogood': 0.00011590843233845262,
#  'evening': 0.0004636337293538105,
#  'dirautopfb': 0.00011590843233845262,
#  'testâ': 0.00011590843233845262,
#  'dirautodiv': 0.00011590843233845262,
#  'dirautobrdivdiv': 0.00023181686467690525,
#  'radhnandanidivdiv': 0.00011590843233845262,
#  'sangeetadivdiv': 0.00011590843233845262,
#  'updeshdivdiv': 0.00011590843233845262,
#  'ruchidivdiv': 0.00011590843233845262,
#  'saurav': 0.0005795421616922632,
#  'meenadivdiv': 0.00011590843233845262,
#  'deepadivdiv': 0.00011590843233845262,
#  'absent': 0.00017386264850767892,
#  'assignment': 0.0006374963778614895,
#  'possible': 0.0005795421616922632,
#  'another': 0.00017386264850767892,
#  'assignmentdivdiv': 0.00011590843233845262,
#  'dirautothank': 0.00011590843233845262,
#  'youâ': 0.00011590843233845262,
#  'dirautomegha': 0.00011590843233845262,
#  'sundriyaldivdivdiv': 0.00011590843233845262,
#  'blockquotediv': 0.00023181686467690525,
#  'midsemester': 0.00017386264850767892,
#  'break': 0.00017386264850767892,
#  'thru': 0.00017386264850767892,
#  'vbducsgmailcom': 0.0004636337293538105,
#  'sep': 0.0006954505940307157,
#  'krishna': 0.0004636337293538105,
#  'ia': 0.0002897710808461316,
#  'discrepancy': 0.00023181686467690525,
#  'tomorrow': 0.00017386264850767892,
#  'final': 0.0008113590263691683,
#  'msccs': 0.0004636337293538105,
#  'iii': 0.001274992755722979,
#  'minor': 0.0012170385395537525,
#  'preference': 0.000927267458707621,
#  'jul': 0.00011590843233845262,
#  'sai': 0.00011590843233845262,
#  'window': 0.00034772529701535785,
#  'youre': 0.0004636337293538105,
#  'getting': 0.0006374963778614895,
#  'check': 0.001274992755722979,
#  'naac': 0.00040567951318458417,
#  'peer': 0.0006374963778614895,
#  'meeting': 0.00023181686467690525,
#  'greeting': 0.0002897710808461316,
#  'behalf': 0.00011590843233845262,
#  'offer': 0.0002897710808461316,
#  'felicitation': 0.00011590843233845262,
#  'part': 0.00023181686467690525,
#  'distinguished': 0.00011590843233845262,
#  'heartening': 0.00011590843233845262,
#  'note': 0.0008113590263691683,
#  'ranked': 0.0002897710808461316,
#  'centre': 0.00023181686467690525,
#  'ranking': 0.00017386264850767892,
#  'cwur': 0.00011590843233845262,
#  'among': 0.00034772529701535785,
#  'q': 0.00023181686467690525,
#  'national': 0.00017386264850767892,
#  'level': 0.00011590843233845262,
#  'also': 0.0013329469718922052,
#  'top': 0.00034772529701535785,
#  'brics': 0.00011590843233845262,
#  'region': 0.00017386264850767892,
#  'happy': 0.00011590843233845262,
#  'based': 0.0005215879455230368,
#  'submitted': 0.00011590843233845262,
#  'feedback': 0.00011590843233845262,
#  'assessment': 0.00034772529701535785,
#  'accreditation': 0.00023181686467690525,
#  'council': 0.00017386264850767892,
#  'decided': 0.00011590843233845262,
#  'octoberâ': 0.00011590843233845262,
#  'since': 0.00034772529701535785,
#  'expected': 0.00011590843233845262,
#  'strengthen': 0.00011590843233845262,
#  'coveted': 0.00011590843233845262,
#  'cherished': 0.00011590843233845262,
#  'duty': 0.00011590843233845262,
#  'contribute': 0.00011590843233845262,
#  'impending': 0.00011590843233845262,
#  'scheduled': 0.00011590843233845262,
#  'convention': 0.00017386264850767892,
#  'hall': 0.00023181686467690525,
#  'vice': 0.00023181686467690525,
#  'regal': 0.00011590843233845262,
#  'lodge': 0.00017386264850767892,
#  'advised': 0.00017386264850767892,
#  'carry': 0.00011590843233845262,
#  'icard': 0.00011590843233845262,
#  'verification': 0.0002897710808461316,
#  'understanding': 0.00017386264850767892,
#  'component': 0.00011590843233845262,
#  'glad': 0.00017386264850767892,
#  'mention': 0.0002897710808461316,
#  'response': 0.0002897710808461316,
#  'earlier': 0.00017386264850767892,
#  'survey': 0.00011590843233845262,
#  'regarding': 0.00034772529701535785,
#  'âoverall': 0.00011590843233845262,
#  'experienceâ': 0.00011590843233845262,
#  'always': 0.00011590843233845262,
#  'remained': 0.00011590843233845262,
#  'âvery': 0.00011590843233845262,
#  'goodâ': 0.00011590843233845262,
#  'reflects': 0.00011590843233845262,
#  'overall': 0.00011590843233845262,
#  'quality': 0.00011590843233845262,
#  'research': 0.00017386264850767892,
#  'programme': 0.00011590843233845262,
#  'offered': 0.00011590843233845262,
#  'valuable': 0.00011590843233845262,
#  'contribution': 0.00011590843233845262,
#  'ensure': 0.00017386264850767892,
#  'completes': 0.00011590843233845262,
#  'exercise': 0.00011590843233845262,
#  'successfully': 0.00011590843233845262,
#  'wishing': 0.00011590843233845262,
#  'best': 0.0009852216748768472,
#  'future': 0.00017386264850767892,
#  'wish': 0.00040567951318458417,
#  'dean': 0.0005795421616922632,
#  'scribe': 0.0013909011880614314,
#  'thing': 0.0002897710808461316,
#  'proper': 0.00011590843233845262,
#  'indentation': 0.00011590843233845262,
#  'everything': 0.00011590843233845262,
#  'left': 0.0004636337293538105,
#  'able': 0.0002897710808461316,
#  'put': 0.0002897710808461316,
#  'equation': 0.00017386264850767892,
#  'lhopital': 0.00011590843233845262,
#  'aligned': 0.00011590843233845262,
#  'coming': 0.00011590843233845262,
#  'internet': 0.00011590843233845262,
#  'tick': 0.00011590843233845262,
#  'latex': 0.00011590843233845262,
#  'table': 0.0005215879455230368,
#  'unemployment': 0.00011590843233845262,
#  'dataset': 0.00017386264850767892,
#  'matlab': 0.003013619240799768,
#  'simulink': 0.002028397565922921,
#  'resource': 0.0005795421616922632,
#  'academia': 0.00040567951318458417,
#  'thu': 0.0005795421616922632,
#  'mar': 0.0008113590263691683,
#  'fyi': 0.0002897710808461316,
#  'homepage': 0.00034772529701535785,
#  'peopleduacinvbhatnagar': 0.00034772529701535785,
#  'anand': 0.0002897710808461316,
#  'geethagovindan': 0.0002897710808461316,
#  'anandgeethagovindangomathworkscom': 0.00017386264850767892,
#  'mathworks': 0.0009852216748768472,
#  'certification': 0.0002897710808461316,
#  'ai': 0.001506809620399884,
#  'robotics': 0.0002897710808461316,
#  'arena': 0.00023181686467690525,
#  'upcoming': 0.00040567951318458417,
#  'webinars': 0.00040567951318458417,
#  'training': 0.0008693132425383947,
#  'web': 0.0008113590263691683,
#  'page': 0.00034772529701535785,
#  'click': 0.0006374963778614895,
#  'career': 0.00017386264850767892,
#  'establishes': 0.00011590843233845262,
#  'standard': 0.00011590843233845262,
#  'excellence': 0.00011590843233845262,
#  'demonstrates': 0.00011590843233845262,
#  'proficiency': 0.00011590843233845262,
#  'customer': 0.00011590843233845262,
#  'industry': 0.00017386264850767892,
#  'employer': 0.00011590843233845262,
#  'featured': 0.00017386264850767892,
#  'everywhere': 0.00011590843233845262,
#  'powering': 0.00011590843233845262,
#  'like': 0.0005215879455230368,
#  'smart': 0.00011590843233845262,
#  'translation': 0.00011590843233845262,
#  'automated': 0.0002897710808461316,
#  'driving': 0.0002897710808461316,
#  'giving': 0.00011590843233845262,
#  'engineer': 0.00011590843233845262,
#  'scientist': 0.0002897710808461316,
#  'set': 0.00023181686467690525,
#  'technique': 0.00017386264850767892,
#  'tackling': 0.00011590843233845262,
#  'task': 0.0002897710808461316,
#  'way': 0.00040567951318458417,
#  'download': 0.0005215879455230368,
#  'ebook': 0.0002897710808461316,
#  'gartner': 0.00023181686467690525,
#  'recognized': 0.00017386264850767892,
#  'visionary': 0.00017386264850767892,
#  'magic': 0.00017386264850767892,
#  'quadrant': 0.00017386264850767892,
#  'january': 0.00034772529701535785,
#  'platform': 0.00011590843233845262,
#  'read': 0.00023181686467690525,
#  'blog': 0.00011590843233845262,
#  'modeling': 0.00023181686467690525,
#  'pneumatic': 0.00023181686467690525,
#  'robot': 0.00017386264850767892,
#  'actuator': 0.00017386264850767892,
#  'join': 0.0002897710808461316,
#  'veer': 0.00011590843233845262,
#  'alakshendra': 0.00011590843233845262,
#  'maitreyee': 0.00011590843233845262,
#  'mordekar': 0.00011590843233845262,
#  'discus': 0.00017386264850767892,
#  'simulation': 0.00023181686467690525,
#  'system': 0.0004636337293538105,
#  'relevant': 0.00011590843233845262,
#  'competition': 0.00034772529701535785,
#  'robocon': 0.00011590843233845262,
#  'watch': 0.0002897710808461316,
#  'video': 0.00034772529701535785,
#  'complimentary': 0.00023181686467690525,
#  'software': 0.00023181686467690525,
#  'supra': 0.00023181686467690525,
#  'saeindia': 0.00023181686467690525,
#  'participating': 0.0002897710808461316,
#  'developing': 0.0002897710808461316,
#  'dcdc': 0.00017386264850767892,
#  'converter': 0.0002897710808461316,
#  'control': 0.0002897710808461316,
#  'register': 0.0013909011880614314,
#  'predictive': 0.00023181686467690525,
#  'maintenance': 0.00023181686467690525,
#  'prognostic': 0.00023181686467690525,
#  'case': 0.0004636337293538105,
#  'study': 0.0006954505940307157,
#  'started': 0.0002897710808461316,
#  'vehicle': 0.00034772529701535785,
#  'dynamic': 0.00011590843233845262,
#  'blockset': 0.00011590843233845262,
#  'vdbs': 0.00011590843233845262,
#  'design': 0.0006954505940307157,
#  'combinatorial': 0.00023181686467690525,
#  'sequential': 0.00011590843233845262,
#  'logic': 0.00011590843233845262,
#  'using': 0.00034772529701535785,
#  'state': 0.00023181686467690525,
#  'stateflow': 0.00011590843233845262,
#  'classroom': 0.00011590843233845262,
#  'ready': 0.00017386264850767892,
#  'arduino': 0.00011590843233845262,
#  'engineering': 0.0005795421616922632,
#  'kit': 0.00011590843233845262,
#  'full': 0.00017386264850767892,
#  'demand': 0.00040567951318458417,
#  'deep': 0.0004636337293538105,
#  'selfpaced': 0.00023181686467690525,
#  'course': 0.0005215879455230368,
#  'comprehensive': 0.00011590843233845262,
#  'introduction': 0.00034772529701535785,
#  'discounted': 0.00011590843233845262,
#  'pricing': 0.00011590843233845262,
#  'basic': 0.00034772529701535785,
#  'onramp': 0.00023181686467690525,
#  'cover': 0.00017386264850767892,
#  'essential': 0.00017386264850767892,
#  'inproduct': 0.00017386264850767892,
#  'latest': 0.00023181686467690525,
#  'release': 0.00017386264850767892,
#  'inperson': 0.00017386264850767892,
#  'taking': 0.00017386264850767892,
#  'near': 0.00023181686467690525,
#  'explore': 0.0005215879455230368,
#  'self': 0.00023181686467690525,
#  'paced': 0.00017386264850767892,
#  'online': 0.0005215879455230368,
#  'enroll': 0.0002897710808461316,
#  'excel': 0.00034772529701535785,
#  'brochure': 0.00023181686467690525,
#  'quick': 0.00023181686467690525,
#  'mobile': 0.0004636337293538105,
#  'campus': 0.00034772529701535785,
#  'wide': 0.0002897710808461316,
#  'license': 0.0002897710808461316,
#  'everyone': 0.00017386264850767892,
#  'anywhere': 0.00017386264850767892,
#  'trial': 0.0002897710808461316,
#  'courseware': 0.0002897710808461316,
#  'lecture': 0.0005215879455230368,
#  'material': 0.0002897710808461316,
#  'ageethagmathworkscom': 0.0002897710808461316,
#  'question': 0.00034772529701535785,
#  'u': 0.000753404810199942,
#  'central': 0.00040567951318458417,
#  'user': 0.0002897710808461316,
#  'inc': 0.0002897710808461316,
#  'see': 0.000753404810199942,
#  'additional': 0.00023181686467690525,
#  'brand': 0.00017386264850767892,
#  'respective': 0.00023181686467690525,
#  'holder': 0.00017386264850767892,
#  'subscribed': 0.0005215879455230368,
#  'commercial': 0.00017386264850767892,
#  'promotion': 0.00017386264850767892,
#  'privacy': 0.00023181686467690525,
#  'policy': 0.00017386264850767892,
#  'private': 0.00017386264850767892,
#  'âbâ': 0.00017386264850767892,
#  'wing': 0.00017386264850767892,
#  'etamin': 0.00017386264850767892,
#  'prestige': 0.00017386264850767892,
#  'park': 0.00017386264850767892,
#  'ii': 0.0019124891335844682,
#  'marathahalli': 0.00017386264850767892,
#  'sarjapur': 0.00017386264850767892,
#  'ring': 0.00017386264850767892,
#  'road': 0.00023181686467690525,
#  'bangalore': 0.00017386264850767892,
#  'karnataka': 0.00017386264850767892,
#  'tel': 0.00017386264850767892,
#  'fax': 0.00017386264850767892,
#  'computational': 0.00034772529701535785,
#  'credit': 0.00040567951318458417,
#  'edit': 0.00040567951318458417,
#  'ive': 0.0002897710808461316,
#  'shared': 0.00040567951318458417,
#  'item': 0.0006374963778614895,
#  'attachment': 0.00034772529701535785,
#  'stored': 0.0002897710808461316,
#  'open': 0.0006374963778614895,
#  'sheet': 0.0014488554042306578,
#  'ci': 0.0005215879455230368,
#  'notespdf': 0.00023181686467690525,
#  'âºï': 0.00011590843233845262,
#  'nov': 0.0008693132425383947,
#  'via': 0.00023181686467690525,
#  'pdf': 0.00017386264850767892,
#  'within': 0.00011590843233845262,
#  'httpdrivegooglecom': 0.00011590843233845262,
#  'lisathung': 0.00040567951318458417,
#  'patton': 0.0002897710808461316,
#  'kulpreet': 0.0002897710808461316,
#  'mail': 0.000753404810199942,
#  'msc': 0.002028397565922921,
#  'last': 0.0005795421616922632,
#  'sunday': 0.0002897710808461316,
#  'july': 0.0004636337293538105,
#  'instruction': 0.00011590843233845262,
#  'mentioned': 0.0005795421616922632,
#  'accepting': 0.00011590843233845262,
#  'today': 0.00034772529701535785,
#  'compiler': 0.00040567951318458417,
#  'made': 0.00017386264850767892,
#  'ask': 0.00040567951318458417,
#  'confirm': 0.00034772529701535785,
#  'entry': 0.0002897710808461316,
#  'till': 0.0002897710808461316,
#  'afternoon': 0.00017386264850767892,
#  'corelation': 0.00023181686467690525,
#  'matrix': 0.00023181686467690525,
#  'yaar': 0.00011590843233845262,
#  'marked': 0.00011590843233845262,
#  'august': 0.0002897710808461316,
#  'group': 0.0038249782671689364,
#  'prolific': 0.00011590843233845262,
#  'penetration': 0.00011590843233845262,
#  'daytoday': 0.00011590843233845262,
#  'life': 0.00017386264850767892,
#  'concern': 0.00017386264850767892,
#  'ethical': 0.00011590843233845262,
#  'use': 0.00034772529701535785,
#  'legal': 0.00017386264850767892,
#  'due': 0.00023181686467690525,
#  'malfunction': 0.00011590843233845262,
#  'threat': 0.00023181686467690525,
#  'colloquium': 0.00017386264850767892,
#  'organized': 0.00040567951318458417,
#  'httpwwwcmsindiaorgaiforbetterworld': 0.00011590843233845262,
#  'httpscyberharvardedutopicsethicsandgovernanceai': 0.00011590843233845262,
#  'httpswwwmediamiteducoursestheethicsandgovernanceofartificialintelligence': 0.00011590843233845262,
#  'aware': 0.00011590843233845262,
#  'frontier': 0.00011590843233845262,
#  'indicate': 0.00011590843233845262,
#  'importance': 0.00011590843233845262,
#  'required': 0.0002897710808461316,
#  'writing': 0.00034772529701535785,
#  'fcfs': 0.00011590843233845262,
#  'basis': 0.00040567951318458417,
#  'dated': 0.00011590843233845262,
#  'author': 0.00023181686467690525,
#  'samyak': 0.0004636337293538105,
#  'sangeeta': 0.00040567951318458417,
#  'saurabh': 0.00023181686467690525,
#  'june': 0.0011011301072152999,
#  'exam': 0.0009852216748768472,
#  'iv': 0.0002897710808461316,
#  'mc': 0.0014488554042306578,
#  'semester': 0.00034772529701535785,
#  'inout': 0.00017386264850767892,
#  'sat': 0.00023181686467690525,
#  'verify': 0.00023181686467690525,
#  'mark': 0.0005215879455230368,
#  'discrepency': 0.00011590843233845262,
#  'roll': 0.00040567951318458417,
#  'assign': 0.00017386264850767892,
#  'abhinav': 0.0002897710808461316,
#  'kumar': 0.002260214430599826,
#  'anju': 0.00017386264850767892,
#  'kumari': 0.00040567951318458417,
#  'gaur': 0.00017386264850767892,
#  'anu': 0.00017386264850767892,
#  'anuradha': 0.00040567951318458417,
#  'aggarwal': 0.0008113590263691683,
#  'asha': 0.00017386264850767892,
#  'singh': 0.000753404810199942,
#  'dua': 0.0004636337293538105,
#  'deepa': 0.0002897710808461316,
#  'divesh': 0.00023181686467690525,
#  'bhagat': 0.00017386264850767892,
#  'ekta': 0.00017386264850767892,
#  'wahi': 0.00017386264850767892,
#  'himanshu': 0.00017386264850767892,
#  'jakhar': 0.00017386264850767892,
#  'agarwal': 0.00023181686467690525,
#  'kour': 0.00017386264850767892,
#  'mayank': 0.00023181686467690525,
#  'kharbanda': 0.00023181686467690525,
#  'moni': 0.00017386264850767892,
#  'tripathi': 0.00017386264850767892,
#  'monika': 0.00017386264850767892,
#  'kandari': 0.00017386264850767892,
#  'naveen': 0.00023181686467690525,
#  'nitin': 0.00017386264850767892,
#  'thakur': 0.00017386264850767892,
#  'preeti': 0.00017386264850767892,
#  'radhnandani': 0.0002897710808461316,
#  'prasad': 0.0004636337293538105,
#  'rishav': 0.00023181686467690525,
#  'kohli': 0.00017386264850767892,
#  'rohit': 0.00040567951318458417,
#  'ronak': 0.00023181686467690525,
#  'ruchi': 0.00034772529701535785,
#  'goswami': 0.00023181686467690525,
#  'ruman': 0.00023181686467690525,
#  'saleem': 0.00023181686467690525,
#  'ahuja': 0.00040567951318458417,
#  'yadav': 0.0005795421616922632,
#  'bharti': 0.00040567951318458417,
#  'meena': 0.0002897710808461316,
#  'smriti': 0.00017386264850767892,
#  'sharma': 0.0006374963778614895,
#  'sunil': 0.00040567951318458417,
#  'swati': 0.0002897710808461316,
#  'gautam': 0.00023181686467690525,
#  'tamanna': 0.00017386264850767892,
#  'tanuj': 0.0002897710808461316,
#  'rohilla': 0.00040567951318458417,
#  'tanya': 0.00034772529701535785,
#  'singhal': 0.00023181686467690525,
#  'uditi': 0.00023181686467690525,
#  'kansal': 0.0002897710808461316,
#  'updesh': 0.0004636337293538105,
#  'vaishali': 0.00023181686467690525,
#  'chawla': 0.00017386264850767892,
#  'vanshika': 0.00017386264850767892,
#  'kushwaha': 0.00017386264850767892,
#  'vineet': 0.00017386264850767892,
#  'karakoti': 0.00017386264850767892,
#  'atin': 0.00017386264850767892,
#  'minocha': 0.00017386264850767892,
#  'aanchal': 0.0002897710808461316,
#  'gupta': 0.0005795421616922632,
#  'jatin': 0.0002897710808461316,
#  'advani': 0.00017386264850767892,
#  'arora': 0.00023181686467690525,
#  'naman': 0.00017386264850767892,
#  'jain': 0.00040567951318458417,
#  'vrinda': 0.00017386264850767892,
#  'yacc': 0.00017386264850767892,
#  'implementation': 0.00017386264850767892,
#  'tutorial': 0.00011590843233845262,
#  'found': 0.00011590843233845262,
#  'quite': 0.00011590843233845262,
#  'useful': 0.00011590843233845262,
#  'classmate': 0.00023181686467690525,
#  'httpswwwyoutubecomwatchvmgimenta': 0.00011590843233845262,
#  'httpswwwyoutubecomwatchvwefvuovllkm': 0.00011590843233845262,
#  'internal': 0.0002897710808461316,
#  'correctionupdation': 0.00011590843233845262,
#  'allowed': 0.00011590843233845262,
#  'tmrw': 0.00011590843233845262,
#  'major': 0.00023181686467690525,
#  'syllabus': 0.0005795421616922632,
#  'ever': 0.00011590843233845262,
#  'done': 0.00017386264850767892,
#  'good': 0.00040567951318458417,
#  'morning': 0.00017386264850767892,
#  'maam': 0.0008113590263691683,
#  'whether': 0.00011590843233845262,
#  'chapter': 0.00011590843233845262,
#  'thank': 0.0004636337293538105,
#  'pfa': 0.0006954505940307157,
#  'examination': 0.00011590843233845262,
#  'network': 0.0002897710808461316,
#  'programming': 0.00011590843233845262,
#  'numerical': 0.00023181686467690525,
#  'computing': 0.0005795421616922632,
#  'unofficial': 0.00011590843233845262,
#  'passed': 0.00011590843233845262,
#  'verbally': 0.00011590843233845262,
#  'teacher': 0.00017386264850767892,
#  'consider': 0.00011590843233845262,
#  'belief': 0.00011590843233845262,
#  'addition': 0.00011590843233845262,
#  'subtraction': 0.00011590843233845262,
#  'topic': 0.0008693132425383947,
#  'might': 0.00023181686467690525,
#  'missed': 0.00011590843233845262,
#  'mentioning': 0.00011590843233845262,
#  'wise': 0.00017386264850767892,
#  'rate': 0.00017386264850767892,
#  'nc': 0.00011590843233845262,
#  'vipin': 0.0005215879455230368,
#  'master': 0.0002897710808461316,
#  'theyre': 0.00017386264850767892,
#  'manualpdf': 0.00011590843233845262,
#  'samplepaper': 0.00011590843233845262,
#  'jan': 0.00034772529701535785,
#  'shashi': 0.000753404810199942,
#  'discrete': 0.00034772529701535785,
#  'mathematics': 0.00023181686467690525,
#  'communication': 0.00011590843233845262,
#  'swiped': 0.00011590843233845262,
#  'shift': 0.00011590843233845262,
#  'cd': 0.00034772529701535785,
#  'election': 0.00011590843233845262,
#  'hometown': 0.00011590843233845262,
#  'patwal': 0.0002897710808461316,
#  'shashicsdugmailcom': 0.00034772529701535785,
#  'anjali': 0.0002897710808461316,
#  'bansal': 0.0002897710808461316,
#  ...}

# %%
cond_prob_class[0]['sapna']
# Out:
# 0.0008693132425383947

# %%
freq_terms_class[0]['sapna']
# Out:
# 14

# %% [markdown]
# Training part is done. We are ready with:
#
#     - vocabulary
#     - class prior probability of each class
#     - cond prob for each term

# %% [markdown]
# ## STEP 7: TESTING CLASSIFIER
#
# Now our model is ready. We will test our data against given labels.
# For every test case, calculate class score (using Bayes theorem) and assign the class to the test case, having maximum score.

# %%
test_set.head()
# Out:
#    sno                                            message  \
# 0  146  megha thanks for being an active member please...
# 1  805  shrikant and manish sent new messages messages...
# 2  337  shrikant sent you a new message conversation w...
# 3  750  delivery status notification failure hello meg...
# 4  373                       mcs_exploratory analysis pfa
#
#                                               tokens  label
# 0  [megha, thanks, active, member, please, view, ...      1
# 1  [shrikant, manish, sent, new, message, message...      1
# 2  [shrikant, sent, new, message, conversation, s...      3
# 3  [delivery, status, notification, failure, hell...      0
# 4                                    [analysis, pfa]      0

# %%
#given a list of tokens of a test doc, predict best suitable class label

def predictClass(token_list):
    class_score = []
    
    #compute posterior prob of each class
    for ci in range(total_classes):
        score = prior_prob[ci]
        
        for token in token_list:
            if token in cond_prob_class[ci]:
                #print(cond_prob_class[0][token])
                score += math.log(cond_prob_class[ci][token])
            else:
                #print("inside else")
                score += math.log(1/(len(vocab)+sum(freq_terms_class[ci].values())))
                
        class_score.append(score)
        
    return np.argmax(class_score)    #return class label with maximum score

# %%
#predict for a test example

example = test_set.tokens.iloc[35]
cls = predictClass(example)
cls
# Out:
# 2

# %%
test_set.label.iloc[35]   #actual label of the test example
# Out:
# 2

# %%
'''
    Determine posterior probability of each test example against all classes and predict the 
    label against which the class probability is maximum

'''       
       
predictions = []                       #to store prediction of each test example\

for test_case in range(test_size): 
    
    token_list = test_set.tokens.iloc[test_case]
    
    #predict the class label for each example and append to the predictions list
    predictions.append(predictClass(token_list))

#predictions

# %% [markdown]
# <b> Testing is over ! </b>
# <br>We have predicted labels for each sample in the test_set.

# %% [markdown]
# ## STEP 8: ACCURACY OF THE CLASSIFIER
#
# Accuracy is the fraction of correct predictions our model out of total predictions.
# Formally, accuracy has the following definition:
# <br><br>
# <center><b> Accuracy = (Number of correct predictions) / (Number of total predictions)

# %%
#calculate accuracy
predict_labels = np.array(predictions)
actual_labels = np.array(test_set.label)

test_accuracy = np.sum(predict_labels == actual_labels)/float(test_size) 

print ("******* Test Set Examples ******* : ", test_size)
print ("******* Test Set Accuracy ******* : ", (test_accuracy*100) ,"%")
# Out:
# ******* Test Set Examples ******* :  137
# ******* Test Set Accuracy ******* :  78.1021897810219 %

# %%
conf_matrix = confusion_matrix(actual_labels, predict_labels)
print(conf_matrix)
# Out:
# [[35  0  2  6  1]
#  [ 0 29  0  0  1]
#  [ 1  0 27  0  0]
#  [ 2 14  2 12  0]
#  [ 0  0  0  1  4]]

# %%
#true_negative
TN = [0]*total_classes
#false_negative
FN = [0]*total_classes
#false_positive
FP = [0]*total_classes
#true_positive
TP = [0]*total_classes

for class_no in range(total_classes):
    for i in range(total_classes):
        for j in range(total_classes):
            if(i==j and i==class_no):
                TP[class_no] = conf_matrix[i][j]
            if(i!=class_no and j!=class_no):
                TN[class_no] += conf_matrix[i][j]
            if(i==class_no and j!=class_no):
                FN[class_no] += conf_matrix[i][j]
            if(j==class_no and i!=class_no):
                FP[class_no] += conf_matrix[i][j]

# %%
correct=0
total=0
for class_no in range(total_classes):
    # Recall is the ratio of the total number of correctly classified positive examples divided by the total number of positive examples. 
    # High Recall indicates the class is correctly recognized (small number of FN)
    recall = (TP[class_no])/(TP[class_no] + FN[class_no])

    # Precision is the the total number of correctly classified positive examples divided by the total number of predicted positive examples. 
    # High Precision indicates an example labeled as positive is indeed positive (small number of FP)
    precision = (TP[class_no])/(TP[class_no] + FP[class_no])

    fmeasure = (2*recall*precision)/(recall+precision)
    correct+=TP[class_no]+TN[class_no]
    total+=TN[class_no] + FN[class_no] + FP[class_no] + TP[class_no]
    print("------ CLASSIFICATION PERFORMANCE OF THE NAIVE BAYES MODEL ------ "\
      "\n class : ", class_no, \
      "\n Recall : ", (recall*100) ,"%" \
      "\n Precision : ", (precision*100) ,"%" \
      "\n F-measure : ", (fmeasure*100) ,"%" )


accuracy = correct/total
print("\n Accuracy : ", (accuracy*100) ,"%" )
#accuracy_score(y_test, y_predict)
# Out:
# ------ CLASSIFICATION PERFORMANCE OF THE NAIVE BAYES MODEL ------
#  class :  0
#  Recall :  79.54545454545455 %
#  Precision :  92.10526315789474 %
#  F-measure :  85.36585365853658 %
# ------ CLASSIFICATION PERFORMANCE OF THE NAIVE BAYES MODEL ------
#  class :  1
#  Recall :  96.66666666666667 %
#  Precision :  67.44186046511628 %
#  F-measure :  79.45205479452055 %
# ------ CLASSIFICATION PERFORMANCE OF THE NAIVE BAYES MODEL ------
#  class :  2
#  Recall :  96.42857142857143 %
#  Precision :  87.09677419354838 %
#  F-measure :  91.52542372881356 %
# ------ CLASSIFICATION PERFORMANCE OF THE NAIVE BAYES MODEL ------
#  class :  3
#  Recall :  40.0 %
#  Precision :  63.1578947368421 %
#  F-measure :  48.97959183673469 %
# ------ CLASSIFICATION PERFORMANCE OF THE NAIVE BAYES MODEL ------
#  class :  4
#  Recall :  80.0 %
#  Precision :  66.66666666666666 %
#  F-measure :  72.72727272727272 %
#
#  Accuracy :  91.24087591240875 %
